# %%
#Not sure exactly which packages I will likely need, but probably most of these
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns
from sklearn import preprocessing
from sklearn.cluster import KMeans

# %% [markdown]
# ## Import and initial description of intake data

# %%
intake_data_raw = pd.read_csv('Austin_Animal_Center_Intakes_20240701.csv')

# %%
#dropping columns of variables not likely to be useful
data_after_drops = intake_data_raw.drop(['Name', 'DateTime', 'Found Location'], axis = 1)
data_after_drops.head()
# Out:
#   Animal ID     MonthYear    Intake Type Intake Condition Animal Type  \
# 0   A786884  January 2019          Stray           Normal         Dog
# 1   A706918     July 2015          Stray           Normal         Dog
# 2   A724273    April 2016          Stray           Normal         Dog
# 3   A857105      May 2022  Public Assist           Normal         Cat
# 4   A682524     June 2014          Stray           Normal         Dog
#
#   Sex upon Intake Age upon Intake                                  Breed  \
# 0   Neutered Male         2 years                             Beagle Mix
# 1   Spayed Female         8 years               English Springer Spaniel
# 2     Intact Male       11 months                            Basenji Mix
# 3   Neutered Male         2 years                     Domestic Shorthair
# 4   Neutered Male         4 years  Doberman Pinsch/Australian Cattle Dog
#
#           Color
# 0      Tricolor
# 1   White/Liver
# 2   Sable/White
# 3  Orange Tabby
# 4      Tan/Gray

# %%
#assessing null data within each variable
data_after_drops.isnull().sum()
# Out:
# Animal ID           0
# MonthYear           0
# Intake Type         0
# Intake Condition    0
# Animal Type         0
# Sex upon Intake     2
# Age upon Intake     1
# Breed               0
# Color               0
# dtype: int64

# %%
def drop_null_data(df):
    #identifies null data in provided data frame, drops it, and reports columns in which the data were null

    #generates a Series with index = df's columns, values = number of nulls per column
    drops = df.isnull().sum()

    #if there are no nulls in the df, print & return original df
    if drops.sum() == 0:
        print("No null values identified")
            
    #if there are nulls in the df, drop them all and print which columns contained nulls and how many were dropped; returns df without nulls    
    else:
        df = df.dropna(axis = 0)
        for index, value in drops.items():
            if value != 0:
                print('"{}" contained {} null value(s)'.format(index, value))
    return df

# %%
intake_data_after_drops = drop_null_data(data_after_drops)
# Out:
# "Sex upon Intake" contained 2 null value(s)
# "Age upon Intake" contained 1 null value(s)

# %%
intake_data_after_drops['Age upon Intake'].unique()
# Out:
# array(['2 years', '8 years', '11 months', '4 years', '4 months',
#        '6 years', '6 months', '4 weeks', '5 months', '14 years',
#        '1 month', '2 months', '18 years', '1 year', '3 years', '4 days',
#        '9 years', '2 weeks', '15 years', '1 day', '5 years', '3 weeks',
#        '9 months', '8 months', '6 days', '7 years', '12 years', '1 week',
#        '10 years', '7 months', '3 months', '10 months', '1 weeks',
#        '5 days', '2 days', '0 years', '11 years', '17 years', '3 days',
#        '13 years', '5 weeks', '19 years', '16 years', '20 years',
#        '-1 years', '22 years', '28 years', '23 years', '30 years',
#        '-2 years', '21 years', '-3 years', '25 years', '24 years',
#        '-4 years'], dtype=object)

# %%
import re

year_pattern = re.compile(r"(-?\d+)\s*(?:year|years)")
month_pattern = re.compile(r"(-?\d+)\s*(?:month|months)")
week_pattern = re.compile(r"(-?\d+)\s*(?:week|weeks)")
day_pattern = re.compile(r"(-?\d+)\s*(?:day|days)")

# Function to convert strings to days
def convert_to_days(age_str):
    if "year" in age_str:
        value = re.search(year_pattern, age_str).group(1)
        return int(value) * 365
    elif "month" in age_str:
        value = re.search(month_pattern, age_str).group(1)
        return int(value) * 30 
    elif "week" in age_str:
        value = re.search(week_pattern, age_str).group(1)
        return int(value) * 7
    elif "day" in age_str:
        value = re.search(day_pattern, age_str).group(1)
        return int(value)
    else:
        print(f"Unknown pattern: {age_str}; -1 days reported")
        return int(-1)

# %%
intake_data_with_negative_ages = intake_data_after_drops

# %%
intake_data_with_negative_ages['Age upon Intake'] = intake_data_with_negative_ages['Age upon Intake'].apply(convert_to_days)
intake_data_with_negative_ages.head()
# Out:
# C:\Users\wisery\AppData\Local\Temp\ipykernel_45908\1705721164.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   intake_data_with_negative_ages['Age upon Intake'] = intake_data_with_negative_ages['Age upon Intake'].apply(convert_to_days)
#   Animal ID     MonthYear    Intake Type Intake Condition Animal Type  \
# 0   A786884  January 2019          Stray           Normal         Dog
# 1   A706918     July 2015          Stray           Normal         Dog
# 2   A724273    April 2016          Stray           Normal         Dog
# 3   A857105      May 2022  Public Assist           Normal         Cat
# 4   A682524     June 2014          Stray           Normal         Dog
#
#   Sex upon Intake  Age upon Intake                                  Breed  \
# 0   Neutered Male              730                             Beagle Mix
# 1   Spayed Female             2920               English Springer Spaniel
# 2     Intact Male              330                            Basenji Mix
# 3   Neutered Male              730                     Domestic Shorthair
# 4   Neutered Male             1460  Doberman Pinsch/Australian Cattle Dog
#
#           Color
# 0      Tricolor
# 1   White/Liver
# 2   Sable/White
# 3  Orange Tabby
# 4      Tan/Gray

# %%
# Dropping rows with negative ages
#negative_aged_pets = intake_data_with_negative_ages.loc[intake_data_with_negative_ages['Age upon Intake'] < 0]
pre = len(intake_data_with_negative_ages)
intake_data_without_negative_ages = intake_data_with_negative_ages.loc[intake_data_with_negative_ages['Age upon Intake'] >= 0]
post= len(intake_data_with_negative_ages)
print(f"Dropped rows due to negative ages: {pre - len(intake_data_with_negative_ages)}")
# Out:
# Dropped rows due to negative ages: 0

# %%
intake_data_without_negative_ages.head()
# Out:
#   Animal ID     MonthYear    Intake Type Intake Condition Animal Type  \
# 0   A786884  January 2019          Stray           Normal         Dog
# 1   A706918     July 2015          Stray           Normal         Dog
# 2   A724273    April 2016          Stray           Normal         Dog
# 3   A857105      May 2022  Public Assist           Normal         Cat
# 4   A682524     June 2014          Stray           Normal         Dog
#
#   Sex upon Intake  Age upon Intake                                  Breed  \
# 0   Neutered Male              730                             Beagle Mix
# 1   Spayed Female             2920               English Springer Spaniel
# 2     Intact Male              330                            Basenji Mix
# 3   Neutered Male              730                     Domestic Shorthair
# 4   Neutered Male             1460  Doberman Pinsch/Australian Cattle Dog
#
#           Color
# 0      Tricolor
# 1   White/Liver
# 2   Sable/White
# 3  Orange Tabby
# 4      Tan/Gray

# %%
intake_data_without_negative_ages
# Out:
#        Animal ID      MonthYear      Intake Type Intake Condition Animal Type  \
# 0        A786884   January 2019            Stray           Normal         Dog
# 1        A706918      July 2015            Stray           Normal         Dog
# 2        A724273     April 2016            Stray           Normal         Dog
# 3        A857105       May 2022    Public Assist           Normal         Cat
# 4        A682524      June 2014            Stray           Normal         Dog
# ...          ...            ...              ...              ...         ...
# 164609   A775309      June 2018  Owner Surrender           Normal         Cat
# 164610   A760677   October 2017            Stray           Normal         Cat
# 164611   A811255  December 2019            Stray          Injured         Cat
# 164612   A763156  December 2017            Stray           Normal         Dog
# 164613   A855904     April 2022            Stray           Normal         Dog
#
#        Sex upon Intake  Age upon Intake  \
# 0        Neutered Male              730
# 1        Spayed Female             2920
# 2          Intact Male              330
# 3        Neutered Male              730
# 4        Neutered Male             1460
# ...                ...              ...
# 164609   Spayed Female              730
# 164610     Intact Male              730
# 164611   Intact Female              150
# 164612     Intact Male              730
# 164613   Intact Female              270
#
#                                         Breed         Color
# 0                                  Beagle Mix      Tricolor
# 1                    English Springer Spaniel   White/Liver
# 2                                 Basenji Mix   Sable/White
# 3                          Domestic Shorthair  Orange Tabby
# 4       Doberman Pinsch/Australian Cattle Dog      Tan/Gray
# ...                                       ...           ...
# 164609                         Turkish Angora         White
# 164610                 Domestic Shorthair Mix    Blue/White
# 164611                     Domestic Shorthair         Black
# 164612        Miniature Poodle/Cocker Spaniel         White
# 164613                 Labrador Retriever Mix           Red
#
# [164599 rows x 9 columns]

# %%
intake_data_without_negative_ages['Intake Condition'].value_counts()
# Out:
# Intake Condition
# Normal        140107
# Injured         9991
# Sick            7426
# Nursing         3878
# Neonatal        1476
# Aged             511
# Medical          394
# Other            346
# Pregnant         148
# Feral            140
# Behavior          70
# Med Attn          55
# Unknown           19
# Med Urgent        13
# Neurologic        11
# Parvo              5
# Space              4
# Agonal             3
# Congenital         1
# Panleuk            1
# Name: count, dtype: int64

# %%
#intake_data = intake_data_without_negative_ages[(intake_data_without_negative_ages['Intake Condition'] != 'Aged') |
#                          (intake_data_without_negative_ages['Age upon Intake'] > 365)]
intake_data_without_negative_ages[(intake_data_without_negative_ages['Intake Condition'] == 'Neonatal') &
                                 (intake_data_without_negative_ages['Age upon Intake'] > 30)].sort_values(by = 'Age upon Intake', ascending = False)
# Out:
#        Animal ID       MonthYear      Intake Type Intake Condition  \
# 1509     A901235      March 2024            Stray         Neonatal
# 91544    A843381  September 2021    Public Assist         Neonatal
# 163216   A908186       June 2024            Stray         Neonatal
# 158650   A885070       July 2023            Stray         Neonatal
# 157132   A887671     August 2023            Stray         Neonatal
# 154251   A902471      April 2024            Stray         Neonatal
# 152378   A853757      March 2022         Wildlife         Neonatal
# 146541   A827914       June 2021  Owner Surrender         Neonatal
# 145075   A878564      April 2023         Wildlife         Neonatal
# 141242   A843380  September 2021    Public Assist         Neonatal
# 11604    A858880       June 2022         Wildlife         Neonatal
# 108245   A845181    October 2021         Wildlife         Neonatal
# 95329    A853946      March 2022         Wildlife         Neonatal
# 122738   A859987       June 2022         Wildlife         Neonatal
# 26128    A845298    October 2021        Abandoned         Neonatal
# 72713    A841441     August 2021            Stray         Neonatal
# 63856    A845043    October 2021    Public Assist         Neonatal
# 61363    A862350       July 2022         Wildlife         Neonatal
# 55274    A845299    October 2021        Abandoned         Neonatal
# 32825    A845041    October 2021    Public Assist         Neonatal
# 90100    A869738   November 2022            Stray         Neonatal
# 90084    A849129    January 2022            Stray         Neonatal
# 125529   A849943    January 2022            Stray         Neonatal
# 128941   A844806    October 2021            Stray         Neonatal
# 159828   A904529        May 2024            Stray         Neonatal
# 156193   A899464      March 2024        Abandoned         Neonatal
# 153570   A902251      April 2024            Stray         Neonatal
# 153574   A902250      April 2024            Stray         Neonatal
# 15865    A848060   December 2021            Stray         Neonatal
# 33926    A845912   November 2021            Stray         Neonatal
# 97921    A848059   December 2021            Stray         Neonatal
# 143412   A848057   December 2021            Stray         Neonatal
# 163813   A848058   December 2021            Stray         Neonatal
# 13491    A843382  September 2021    Public Assist         Neonatal
# 161885   A904776       June 2024  Owner Surrender         Neonatal
#
#        Animal Type Sex upon Intake  Age upon Intake  \
# 1509           Cat   Intact Female              730
# 91544          Dog     Intact Male              730
# 163216         Cat   Intact Female              730
# 158650         Cat   Intact Female              730
# 157132         Cat   Intact Female              730
# 154251         Cat   Intact Female              730
# 152378       Other     Intact Male              730
# 146541         Dog   Intact Female              730
# 145075       Other         Unknown              730
# 141242         Dog   Intact Female              730
# 11604        Other         Unknown              730
# 108245       Other         Unknown              730
# 95329        Other         Unknown              730
# 122738       Other         Unknown              730
# 26128          Cat   Intact Female              730
# 72713          Dog   Spayed Female              730
# 63856          Cat         Unknown              730
# 61363        Other         Unknown              730
# 55274          Cat   Intact Female              730
# 32825          Cat         Unknown              730
# 90100          Dog   Intact Female              365
# 90084          Dog   Intact Female              365
# 125529         Dog     Intact Male              365
# 128941         Dog   Intact Female              365
# 159828         Cat   Intact Female              365
# 156193         Cat   Intact Female              365
# 153570         Dog     Intact Male              300
# 153574         Dog     Intact Male              300
# 15865        Other     Intact Male              180
# 33926          Dog     Intact Male              180
# 97921        Other     Intact Male              180
# 143412       Other     Intact Male              180
# 163813       Other     Intact Male              180
# 13491          Dog     Intact Male              150
# 161885         Dog   Neutered Male               90
#
#                                      Breed              Color
# 1509                    Domestic Shorthair  Brown Tabby/White
# 91544                  Chihuahua Shorthair          Tan/White
# 163216                  Domestic Shorthair             Calico
# 158650                  Domestic Shorthair        Brown Tabby
# 157132                  Domestic Shorthair        Black/White
# 154251                  Domestic Shorthair        Brown Tabby
# 152378                                 Bat        Brown/Brown
# 146541                               Boxer        Brown/White
# 145075                             Raccoon         Black/Gray
# 141242                 Chihuahua Shorthair          Tan/White
# 11604                                  Bat        Brown/Brown
# 108245                                 Bat        Brown/Brown
# 95329                                  Bat        Brown/Brown
# 122738                                 Bat        Brown/Brown
# 26128                   Domestic Shorthair             Torbie
# 72713                    Queensland Heeler               Blue
# 63856                   Domestic Shorthair  Brown Tabby/White
# 61363                                  Bat        Brown/Brown
# 55274                   Domestic Shorthair             Torbie
# 32825                   Domestic Shorthair       Orange Tabby
# 90100   Australian Shepherd/Siberian Husky     Blue Merle/Tan
# 90084                Yorkshire Terrier Mix          Brown/Tan
# 125529                      Siberian Husky          Red/White
# 128941                            Pit Bull        Brown/Brown
# 159828                  Domestic Shorthair       Orange Tabby
# 156193                  Domestic Shorthair   Blue Tabby/White
# 153570                  Labrador Retriever                Tan
# 153574                  Labrador Retriever              Black
# 15865                           Guinea Pig       Black/Orange
# 33926   Labrador Retriever/Chinese Sharpei        Brown/Brown
# 97921                           Guinea Pig       Orange/White
# 143412                          Guinea Pig      Chocolate/Tan
# 163813                          Guinea Pig       Orange/White
# 13491                  Chihuahua Shorthair          White/Tan
# 161885                      Rottweiler Mix        Black/Brown

# %% [markdown]
# ## Import and initial description of outcome data

# %%
raw_outcome_data = pd.read_csv('Austin_Animal_Center_Outcomes_20240701.csv')

# %%
raw_outcome_data.head(100)
# Out:
#    Animal ID    Name                DateTime MonthYear Date of Birth  \
# 0    A794011   Chunk  05/08/2019 06:20:00 PM  May 2019    05/02/2017
# 1    A776359   Gizmo  07/18/2018 04:02:00 PM  Jul 2018    07/12/2017
# 2    A821648     NaN  08/16/2020 11:38:00 AM  Aug 2020    08/16/2019
# 3    A720371   Moose  02/13/2016 05:59:00 PM  Feb 2016    10/08/2015
# 4    A674754     NaN  03/18/2014 11:47:00 AM  Mar 2014    03/12/2014
# ..       ...     ...                     ...       ...           ...
# 95   A801948    Boie  07/09/2021 01:24:00 PM  Jul 2021    02/12/2019
# 96   A809230    *Moo  11/24/2019 04:36:00 PM  Nov 2019    11/21/2015
# 97   A783412   *Yams  12/16/2018 12:45:00 PM  Dec 2018    10/30/2008
# 98   A686459  *Lovey  09/21/2014 05:39:00 PM  Sep 2014    07/15/2014
# 99   A742736   Astro  01/31/2017 05:02:00 PM  Jan 2017    05/01/2016
#
#    Outcome Type Outcome Subtype Animal Type Sex upon Outcome Age upon Outcome  \
# 0     Rto-Adopt             NaN         Cat    Neutered Male          2 years
# 1      Adoption             NaN         Dog    Neutered Male           1 year
# 2    Euthanasia             NaN       Other          Unknown           1 year
# 3      Adoption             NaN         Dog    Neutered Male         4 months
# 4      Transfer         Partner         Cat      Intact Male           6 days
# ..          ...             ...         ...              ...              ...
# 95     Adoption             NaN         Dog    Neutered Male          2 years
# 96     Adoption             NaN         Dog    Neutered Male          4 years
# 97     Adoption             NaN         Cat    Neutered Male         10 years
# 98     Adoption          Foster         Cat    Spayed Female         2 months
# 99     Adoption             NaN         Dog    Neutered Male         9 months
#
#                                  Breed                Color
# 0               Domestic Shorthair Mix    Brown Tabby/White
# 1              Chihuahua Shorthair Mix          White/Brown
# 2                              Raccoon                 Gray
# 3   Anatol Shepherd/Labrador Retriever                 Buff
# 4               Domestic Shorthair Mix         Orange Tabby
# ..                                 ...                  ...
# 95               Australian Kelpie Mix  Brown Brindle/White
# 96                      Siberian Husky           Gray/White
# 97              Domestic Shorthair Mix                Black
# 98              Domestic Shorthair Mix               Tortie
# 99  Yorkshire Terrier/Miniature Poodle           Brown/Gray
#
# [100 rows x 12 columns]

# %%
outcome_data_after_drops = raw_outcome_data.drop(['Name', 'MonthYear'], axis = 1)
outcome_data_after_drops.head()
# Out:
#   Animal ID                DateTime Date of Birth Outcome Type  \
# 0   A794011  05/08/2019 06:20:00 PM    05/02/2017    Rto-Adopt
# 1   A776359  07/18/2018 04:02:00 PM    07/12/2017     Adoption
# 2   A821648  08/16/2020 11:38:00 AM    08/16/2019   Euthanasia
# 3   A720371  02/13/2016 05:59:00 PM    10/08/2015     Adoption
# 4   A674754  03/18/2014 11:47:00 AM    03/12/2014     Transfer
#
#   Outcome Subtype Animal Type Sex upon Outcome Age upon Outcome  \
# 0             NaN         Cat    Neutered Male          2 years
# 1             NaN         Dog    Neutered Male           1 year
# 2             NaN       Other          Unknown           1 year
# 3             NaN         Dog    Neutered Male         4 months
# 4         Partner         Cat      Intact Male           6 days
#
#                                 Breed              Color
# 0              Domestic Shorthair Mix  Brown Tabby/White
# 1             Chihuahua Shorthair Mix        White/Brown
# 2                             Raccoon               Gray
# 3  Anatol Shepherd/Labrador Retriever               Buff
# 4              Domestic Shorthair Mix       Orange Tabby

# %%
outcome_data_after_drops.isnull().sum()
# Out:
# Animal ID               0
# DateTime                0
# Date of Birth           0
# Outcome Type           39
# Outcome Subtype     88751
# Animal Type             0
# Sex upon Outcome        2
# Age upon Outcome       10
# Breed                   0
# Color                   0
# dtype: int64

# %%
outcome_data_after_drops.loc[outcome_data_after_drops['Outcome Type'].isnull() == True]
# Out:
#        Animal ID                DateTime Date of Birth Outcome Type  \
# 3729     A828272  02/02/2021 06:01:00 PM    01/12/2020          NaN
# 4890     A874518  02/14/2023 09:10:00 AM    02/13/2022          NaN
# 9848     A700839  01/12/2021 06:07:00 PM    04/20/2014          NaN
# 15929    A841539  08/30/2021 06:10:00 PM    08/29/2019          NaN
# 21845    A827712  01/05/2021 05:47:00 PM    02/29/2020          NaN
# 26293    A828543  01/27/2021 02:24:00 PM    07/20/2020          NaN
# 28066    A679066  05/16/2014 12:00:00 AM    04/16/2014          NaN
# 32164    A828570  01/27/2021 04:59:00 PM    09/20/2020          NaN
# 38121    A828974  02/03/2021 03:55:00 PM    01/30/2019          NaN
# 48981    A671017  01/20/2014 08:27:00 AM    01/17/2013          NaN
# 51451    A836061  07/24/2021 06:49:00 PM    06/05/2019          NaN
# 72791    A815725  03/24/2020 01:42:00 PM    03/24/2019          NaN
# 73544    A812591  01/05/2021 05:25:00 PM    06/26/2019          NaN
# 78980    A830075  03/02/2021 01:34:00 PM    03/02/2020          NaN
# 79001    A836960  06/26/2021 11:28:00 AM    06/16/2019          NaN
# 93616    A829148  02/12/2021 12:25:00 PM    12/03/2020          NaN
# 99350    A828280  02/20/2021 12:20:00 PM    10/20/2016          NaN
# 101472   A903014  04/24/2024 10:33:00 AM    04/24/2019          NaN
# 102381   A830563  03/11/2021 01:32:00 PM    12/11/2019          NaN
# 103157   A674209  03/09/2014 06:15:00 PM    03/09/2014          NaN
# 104594   A837337  06/21/2021 04:13:00 PM    04/21/2021          NaN
# 106925   A900468  03/19/2024 07:00:00 PM    03/18/2024          NaN
# 109880   A872667  01/13/2023 12:12:00 PM    05/26/2009          NaN
# 110193   A896559  03/24/2024 01:34:00 PM    01/17/2022          NaN
# 116991   A830164  03/03/2021 02:28:00 PM    01/19/2021          NaN
# 119112   A719747  02/13/2021 10:58:00 AM    10/26/2015          NaN
# 121283   A686025  08/16/2014 08:35:00 AM    08/15/2013          NaN
# 149723   A875192  02/23/2023 03:46:00 PM    02/23/2022          NaN
# 152666   A802210  06/13/2023 10:09:00 AM    07/30/2019          NaN
# 153275   A906001  06/08/2024 04:44:00 PM    05/28/2022          NaN
# 153586   A891335  12/09/2023 02:25:00 PM    09/04/2023          NaN
# 153638   A882904  06/16/2023 06:48:00 PM    06/10/2021          NaN
# 156108   A890645  12/14/2023 04:22:00 PM    09/11/2023          NaN
# 156452   A882682  06/07/2023 07:22:00 PM    06/07/2021          NaN
# 156797   A894378  12/19/2023 05:09:00 PM    12/07/2021          NaN
# 161602   A900469  03/19/2024 07:00:00 PM    03/18/2024          NaN
# 161688   A900092  03/22/2024 05:26:00 PM    09/14/2023          NaN
# 164106   A904825  06/02/2024 03:08:00 PM    04/19/2024          NaN
# 164173   A904823  06/02/2024 03:06:00 PM    04/19/2024          NaN
#
#        Outcome Subtype Animal Type Sex upon Outcome Age upon Outcome  \
# 3729               NaN         Dog    Neutered Male           1 year
# 4890               NaN        Bird          Unknown           1 year
# 9848               NaN         Dog    Neutered Male          6 years
# 15929              NaN         Dog      Intact Male          2 years
# 21845              NaN         Dog    Spayed Female        10 months
# 26293              NaN         Dog    Spayed Female         6 months
# 28066              NaN       Other          Unknown          4 weeks
# 32164              NaN         Dog    Neutered Male         4 months
# 38121              Snr         Cat    Spayed Female          2 years
# 48981              NaN       Other          Unknown           1 year
# 51451              NaN         Cat    Spayed Female          2 years
# 72791              NaN       Other          Unknown           1 year
# 73544              NaN         Dog    Spayed Female           1 year
# 78980              NaN         Dog      Intact Male           1 year
# 79001              NaN         Dog      Intact Male          2 years
# 93616              NaN         Dog    Neutered Male         2 months
# 99350              NaN         Dog    Neutered Male          4 years
# 101472             NaN         Dog          Unknown          5 years
# 102381             NaN         Dog      Intact Male           1 year
# 103157             NaN       Other          Unknown          0 years
# 104594             NaN         Cat      Intact Male          1 month
# 106925             NaN         Cat          Unknown            1 day
# 109880             NaN         Cat    Spayed Female         13 years
# 110193             NaN       Other          Unknown          2 years
# 116991             NaN         Dog          Unknown          1 month
# 119112             NaN         Dog    Spayed Female          5 years
# 121283             NaN       Other          Unknown           1 year
# 149723             NaN         Dog          Unknown           1 year
# 152666             NaN         Cat    Neutered Male          3 years
# 153275             NaN         Dog    Intact Female          2 years
# 153586             NaN         Cat    Spayed Female         3 months
# 153638             NaN         Dog    Neutered Male          2 years
# 156108          Foster         Cat    Spayed Female         3 months
# 156452             NaN         Dog      Intact Male          2 years
# 156797             NaN         Dog    Spayed Female          2 years
# 161602             NaN         Cat          Unknown            1 day
# 161688             NaN         Dog    Neutered Male         6 months
# 164106             NaN         Cat    Intact Female          1 month
# 164173             NaN         Cat    Intact Female          1 month
#
#                                     Breed         Color
# 3729                        Blue Lacy Mix    Blue/White
# 4890                              Waxwing     Tan/Black
# 9848                         Pit Bull Mix          Blue
# 15929                     German Shepherd     Black/Tan
# 21845                     German Shepherd     Tan/Black
# 26293    Labrador Retriever/Border Collie   Black/White
# 28066                           Rabbit Sh         Brown
# 32164                American Bulldog Mix   Black/White
# 38121                  Domestic Shorthair         Black
# 48981                             Fox Mix   Brown/Black
# 51451                  Domestic Shorthair        Tortie
# 72791                                 Bat         Black
# 73544                American Bulldog Mix   White/Black
# 78980             Chihuahua Shorthair Mix           Tan
# 79001                             Pug Mix   Black/White
# 93616                            Pit Bull    Blue/White
# 99350              Labrador Retriever Mix  Yellow/White
# 101472               American Bulldog Mix         Brown
# 102381                           Pit Bull         Black
# 103157                            Bat Mix         Brown
# 104594               Domestic Medium Hair   Black Smoke
# 106925                 Domestic Shorthair         Brown
# 109880                 Domestic Shorthair        Tortie
# 110193                             Coyote         Brown
# 116991                            Pug Mix   Black/White
# 119112      American Pit Bull Terrier Mix   White/Brown
# 121283                            Bat Mix         Brown
# 149723                          Pekingese   Black/White
# 152666                 Domestic Shorthair   Cream Tabby
# 153275                     Siberian Husky         White
# 153586                 Domestic Shorthair   Black/White
# 153638                        Mastiff Mix           Tan
# 156108                        Siamese Mix    Lynx Point
# 156452                Doberman Pinsch Mix   Black/Brown
# 156797  Cairn Terrier/Chihuahua Shorthair         White
# 161602                 Domestic Shorthair        Calico
# 161688                     Great Pyrenees         White
# 164106             Domestic Shorthair Mix        Torbie
# 164173             Domestic Shorthair Mix   Brown Tabby

# %%
outcome_data_after_drops['Outcome Type'].unique()
# Out:
# array(['Rto-Adopt', 'Adoption', 'Euthanasia', 'Transfer',
#        'Return to Owner', 'Died', 'Disposal', 'Missing', 'Relocate', nan,
#        'Stolen', 'Lost'], dtype=object)

# %%
outcome_data_after_drops.loc[outcome_data_after_drops['Outcome Subtype'] == 'Foster']
# Out:
#        Animal ID                DateTime Date of Birth Outcome Type  \
# 6        A814515  05/06/2020 07:59:00 AM    03/01/2018     Adoption
# 21       A822928  01/24/2022 11:49:00 AM    09/15/2010     Adoption
# 27       A765349  06/08/2018 01:04:00 PM    01/18/2009     Adoption
# 35       A812473  03/05/2020 04:15:00 PM    01/26/2010     Adoption
# 38       A789298  04/23/2019 11:59:00 AM    02/15/2019     Adoption
# ...          ...                     ...           ...          ...
# 164076   A901535  06/01/2024 01:14:00 PM    04/03/2023     Adoption
# 164077   A903054  06/01/2024 02:38:00 PM    06/01/2023     Adoption
# 164082   A761967  06/01/2024 03:12:00 PM    11/12/2013     Adoption
# 164095   A887625  06/02/2024 12:42:00 PM    08/24/2018     Adoption
# 164185   A904483  06/04/2024 12:01:00 PM    04/03/2024     Adoption
#
#        Outcome Subtype Animal Type Sex upon Outcome Age upon Outcome  \
# 6               Foster         Dog    Neutered Male          2 years
# 21              Foster         Cat    Spayed Female         11 years
# 27              Foster         Dog    Neutered Male          9 years
# 35              Foster         Dog    Neutered Male         10 years
# 38              Foster         Dog    Neutered Male         2 months
# ...                ...         ...              ...              ...
# 164076          Foster         Cat    Spayed Female           1 year
# 164077          Foster         Dog    Spayed Female           1 year
# 164082          Foster         Dog    Neutered Male         10 years
# 164095          Foster         Dog    Neutered Male          5 years
# 164185          Foster         Cat    Intact Female         2 months
#
#                                        Breed        Color
# 6       American Foxhound/Labrador Retriever  White/Brown
# 21                        Domestic Shorthair       Torbie
# 27                   Chihuahua Shorthair Mix     Tricolor
# 35                       Chihuahua Shorthair        Brown
# 38                    Labrador Retriever Mix  Brown/White
# ...                                      ...          ...
# 164076                            Bengal Mix  Brown Tabby
# 164077                       German Shepherd        Sable
# 164082                Labrador Retriever Mix  Black/White
# 164095                              Pit Bull   Blue/White
# 164185                    Domestic Shorthair        Black
#
# [16394 rows x 10 columns]

# %%
outcome_data_after_drops.loc[(outcome_data_after_drops['Outcome Type'].isnull()) & (outcome_data_after_drops['Outcome Subtype'].isnull()==False)]
# Out:
#        Animal ID MonthYear Date of Birth Outcome Type Outcome Subtype  \
# 38121    A828974  Feb 2021    01/30/2019          NaN             Snr
# 156108   A890645  Dec 2023    09/11/2023          NaN          Foster
#
#        Animal Type Sex upon Outcome Age upon Outcome               Breed  \
# 38121          Cat    Spayed Female          2 years  Domestic Shorthair
# 156108         Cat    Spayed Female         3 months         Siamese Mix
#
#              Color
# 38121        Black
# 156108  Lynx Point

# %%
lost_to_follow_up = outcome_data_after_drops.loc[outcome_data_after_drops['Outcome Type'].isnull()]
# Out:
# (0, 10)

# %%
drops = lost_to_follow_up.index
breaking_my_data = outcome_data_after_drops.drop(drops, axis = 0)
breaking_my_data.isnull().sum()
# Out:
# Animal ID               0
# MonthYear               0
# Date of Birth           0
# Outcome Type            0
# Outcome Subtype     88714
# Animal Type             0
# Sex upon Outcome        2
# Age upon Outcome       10
# Breed                   0
# Color                   0
# dtype: int64

# %%
outcome_data_after_drops = breaking_my_data

# %%
outcome_data_after_drops.loc[outcome_data_after_drops['Sex upon Outcome'].isnull()]
# Out:
#       Animal ID MonthYear Date of Birth     Outcome Type Outcome Subtype  \
# 51935   A830333  Oct 2022    10/12/2022  Return to Owner             NaN
# 78121   A667395  Nov 2013    11/17/2006  Return to Owner             NaN
#
#       Animal Type Sex upon Outcome Age upon Outcome      Breed        Color
# 51935         Dog              NaN              NaN     Kuvasz      Unknown
# 78121         Dog              NaN          7 years  Dachshund  Brown Merle

# %%
drops = outcome_data_after_drops.loc[outcome_data_after_drops['Sex upon Outcome'].isnull()].index
drops
breaking_my_data = outcome_data_after_drops.drop(drops, axis = 0)
breaking_my_data.isnull().sum()
# Out:
# Animal ID               0
# MonthYear               0
# Date of Birth           0
# Outcome Type            0
# Outcome Subtype     88712
# Animal Type             0
# Sex upon Outcome        0
# Age upon Outcome        9
# Breed                   0
# Color                   0
# dtype: int64

# %%
outcome_data_after_drops = breaking_my_data

# %%
outcome_data_after_drops.isnull().sum()
# Out:
# Animal ID           0
# MonthYear           0
# Date of Birth       0
# Outcome Type        0
# Outcome Subtype     0
# Animal Type         0
# Sex upon Outcome    0
# Age upon Outcome    0
# Breed               0
# Color               0
# dtype: int64

# %%
outcome_data_no_nulls = outcome_data_after_drops
#&(outcome_data_after_drops['Outcome Type'] != "Euthanasia")]

# %%
outcome_data_no_nulls['Age upon Outcome'].unique()
# Out:
# array(['2 years', '1 year', '4 months', '6 days', '7 years', '2 months',
#        '2 days', '3 weeks', '11 years', '9 months', '4 weeks', '2 weeks',
#        '6 months', '3 months', '9 years', '10 years', '8 years',
#        '3 years', '7 months', '6 years', '4 years', '1 month', '12 years',
#        '5 years', '1 weeks', '5 months', '5 days', '15 years',
#        '10 months', '4 days', '16 years', '1 day', '8 months', '13 years',
#        '1 week', '14 years', '11 months', '3 days', '0 years', '5 weeks',
#        '17 years', '18 years', '20 years', '22 years', '19 years',
#        '28 years', '23 years', '30 years', '24 years', '25 years',
#        '21 years', 'Unknown'], dtype=object)

# %%
breaking_my_data = outcome_data_no_nulls

# %%
breaking_my_data.loc[breaking_my_data['Age upon Outcome'] == "-4 years"]
# Out:
# Empty DataFrame
# Columns: [Animal ID, MonthYear, Date of Birth, Outcome Type, Outcome Subtype, Animal Type, Sex upon Outcome, Age upon Outcome, Breed, Color]
# Index: []

# %%
drops = breaking_my_data.loc[breaking_my_data['Age upon Outcome']=="-4 years"].index
#drops
breaking_my_data = breaking_my_data.drop(drops, axis = 0)

# %%
outcome_data_no_nulls = breaking_my_data
