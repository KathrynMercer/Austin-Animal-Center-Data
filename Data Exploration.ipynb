# %%
#Not sure exactly which packages I will likely need, but probably most of these
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns
from sklearn import preprocessing
from sklearn.cluster import KMeans

# %% [markdown]
# ### Import and initial description of intake data

# %%
#read both the intake and outcome data files
intake_data_raw = pd.read_csv('Austin_Animal_Center_Intakes_20240701.csv')
outcome_data_raw = pd.read_csv('Austin_Animal_Center_Outcomes_20240701.csv')

# %%
intake_data_raw.head()
intake_length = len(intake_data_raw)
#intake_length #164614
#Name and Found Location are potentially sensitive information, so I will drop these. 
#Animal ID is also potentially sensitive information, but I can use it to join the intake and outcome data sets, so I will keep it for now. It should not appear in the final data set.
#MonthYear and DateTime are redundant, so I will drop MonthYear since DateTime should be easy to convert from str to timestamp or other numerical.

# %%
outcome_length = len(outcome_data_raw)
outcome_data_raw.head()
#outcome_length #164228
#Name is again potentially sensitive. The Animal ID will be used for merging.
#MonthYear and DateTime are again redundant.
#The outcome data is shorter than the intake data, likely because some pets are actively in the shelter (so they have intake but no outcome yet)
# Out:
#   Animal ID   Name                DateTime MonthYear Date of Birth  \
# 0   A794011  Chunk  05/08/2019 06:20:00 PM  May 2019    05/02/2017
# 1   A776359  Gizmo  07/18/2018 04:02:00 PM  Jul 2018    07/12/2017
# 2   A821648    NaN  08/16/2020 11:38:00 AM  Aug 2020    08/16/2019
# 3   A720371  Moose  02/13/2016 05:59:00 PM  Feb 2016    10/08/2015
# 4   A674754    NaN  03/18/2014 11:47:00 AM  Mar 2014    03/12/2014
#
#   Outcome Type Outcome Subtype Animal Type Sex upon Outcome Age upon Outcome  \
# 0    Rto-Adopt             NaN         Cat    Neutered Male          2 years
# 1     Adoption             NaN         Dog    Neutered Male           1 year
# 2   Euthanasia             NaN       Other          Unknown           1 year
# 3     Adoption             NaN         Dog    Neutered Male         4 months
# 4     Transfer         Partner         Cat      Intact Male           6 days
#
#                                 Breed              Color
# 0              Domestic Shorthair Mix  Brown Tabby/White
# 1             Chihuahua Shorthair Mix        White/Brown
# 2                             Raccoon               Gray
# 3  Anatol Shepherd/Labrador Retriever               Buff
# 4              Domestic Shorthair Mix       Orange Tabby

# %% [markdown]
# ### Duplicate Detection & Removal

# %%
intake_data_raw['Animal ID'].value_counts()
#Animal ID is not unique because a single animal may go through the shelter system multiple times
# Out:
# Animal ID
# A721033    33
# A718223    14
# A718877    12
# A705625    11
# A706536    11
#            ..
# A714773     1
# A765646     1
# A732323     1
# A698657     1
# A855904     1
# Name: count, Length: 147862, dtype: int64

# %%
#Looking more closely at the most frequently intaken pet, we see these are not duplicate data, but actually 33 unique visits to the shelter. 
#The other pets with multiple entries of the same Animal ID tell similar stories. 
intake_data_raw.loc[(intake_data_raw['Animal ID'] == 'A721033')].sort_values(by = 'DateTime')
# Out:
#        Animal ID     Name                DateTime       MonthYear  \
# 118002   A721033  Lil Bit  01/09/2017 02:26:00 PM    January 2017
# 125351   A721033  Lil Bit  01/26/2017 06:55:00 AM    January 2017
# 48856    A721033  Lil Bit  01/30/2017 11:05:00 PM    January 2017
# 110181   A721033  Lil Bit  02/06/2017 10:13:00 AM   February 2017
# 30692    A721033  Lil Bit  02/12/2019 10:21:00 AM   February 2019
# 69901    A721033  Lil Bit  02/16/2019 10:30:00 AM   February 2019
# 102945   A721033  Lil Bit  02/20/2016 10:44:00 AM   February 2016
# 150333   A721033  Lil Bit  02/22/2018 10:28:00 AM   February 2018
# 5518     A721033  Lil Bit  02/24/2019 09:53:00 PM   February 2019
# 146777               1500 Red River Street in Austin (TX)  Public Assist
# 121342                    6010 E Riverside in Austin (TX)  Public Assist
# 45736   East 7Th Street And Pleasant Valley in Austin ...  Public Assist
# 115943         Justin Lane And North Lamar in Austin (TX)  Public Assist
# 32505                     863 Airport Blvd in Austin (TX)  Public Assist
# 24133                    Shady And Airport in Austin (TX)  Public Assist
# 32881               1135 Airport Boulevard in Austin (TX)  Public Assist
# 31062               6200 E. Ben White Blvd in Austin (TX)  Public Assist
# 99184                         9300 S Ih 35 in Austin (TX)  Public Assist
# 44244   S Pleasant Valley Rd And E Riverside Dr in Aus...  Public Assist
# 76047                         1144 Airport in Austin (TX)  Public Assist
#
#        Intake Condition Animal Type Sex upon Intake Age upon Intake  \
# 118002          Injured         Dog   Neutered Male          1 year
# 125351           Normal         Dog   Neutered Male          1 year
# 48856            Normal         Dog   Neutered Male          1 year
# 110181           Normal         Dog   Neutered Male          1 year
# 30692            Normal         Dog   Neutered Male         3 years
# 69901            Normal         Dog   Neutered Male         3 years
# 102945           Normal         Dog   Neutered Male        9 months
# 150333           Normal         Dog   Neutered Male         2 years
# 5518             Normal         Dog   Neutered Male         3 years
# 13100            Normal         Dog   Neutered Male         2 years
# 48146            Normal         Dog   Neutered Male         3 years
# 60977            Normal         Dog   Neutered Male         2 years
# 28649            Normal         Dog   Neutered Male          1 year
# 16155            Normal         Dog   Neutered Male         2 years
# 62129            Normal         Dog   Neutered Male         2 years
# 85455            Normal         Dog   Neutered Male         2 years
# 61423            Normal         Dog   Neutered Male         3 years
# 15563            Normal         Dog   Neutered Male         4 years
# 118283           Normal         Dog   Neutered Male         3 years
# 38877            Normal         Dog   Neutered Male          1 year
# 42912            Normal         Dog   Neutered Male         4 years
# 137932           Normal         Dog   Neutered Male         3 years
# 146777           Normal         Dog   Neutered Male         3 years
# 121342           Normal         Dog   Neutered Male          1 year
# 45736            Normal         Dog   Neutered Male         3 years
# 115943           Normal         Dog   Neutered Male         4 years
# 32505            Normal         Dog   Neutered Male         3 years
# 24133            Normal         Dog   Neutered Male         3 years
# 32881            Normal         Dog   Neutered Male         4 years
# 31062            Normal         Dog   Neutered Male          1 year
# 99184            Normal         Dog   Neutered Male         3 years
# 44244            Normal         Dog   Neutered Male          1 year
# 76047            Normal         Dog   Neutered Male         3 years
#
#                   Breed                   Color
# 118002  Rat Terrier Mix  Tricolor/Brown Brindle
# 125351  Rat Terrier Mix  Tricolor/Brown Brindle
# 48856   Rat Terrier Mix  Tricolor/Brown Brindle
# 110181  Rat Terrier Mix  Tricolor/Brown Brindle
# 30692   Rat Terrier Mix  Tricolor/Brown Brindle
# 69901   Rat Terrier Mix  Tricolor/Brown Brindle
# 102945  Rat Terrier Mix  Tricolor/Brown Brindle
# 150333  Rat Terrier Mix  Tricolor/Brown Brindle
# 5518    Rat Terrier Mix  Tricolor/Brown Brindle
# 13100   Rat Terrier Mix  Tricolor/Brown Brindle
# 48146   Rat Terrier Mix  Tricolor/Brown Brindle
# 60977   Rat Terrier Mix  Tricolor/Brown Brindle
# 28649   Rat Terrier Mix  Tricolor/Brown Brindle
1 year  Rat Terrier Mix  Tricolor/Brown Brindle
# 42029            1 year  Rat Terrier Mix  Tricolor/Brown Brindle
# 83153            1 year  Rat Terrier Mix  Tricolor/Brown Brindle
# 67815            1 year  Rat Terrier Mix  Tricolor/Brown Brindle
# 136111          3 years  Rat Terrier Mix  Tricolor/Brown Brindle
# 37003           3 years  Rat Terrier Mix  Tricolor/Brown Brindle
# 74377          9 months  Rat Terrier Mix  Tricolor/Brown Brindle
# 90560           2 years  Rat Terrier Mix  Tricolor/Brown Brindle
# 51640           3 years  Rat Terrier Mix  Tricolor/Brown Brindle
# 108849          2 years  Rat Terrier Mix  Tricolor/Brown Brindle
# 16690           3 years  Rat Terrier Mix  Tricolor/Brown Brindle
# 95326            1 year  Rat Terrier Mix  Tricolor/Brown Brindle
# 27354           2 years  Rat Terrier Mix  Tricolor/Brown Brindle
# 59307           2 years  Rat Terrier Mix  Tricolor/Brown Brindle
# 130187          2 years  Rat Terrier Mix  Tricolor/Brown Brindle
# 51367           2 years  Rat Terrier Mix  Tricolor/Brown Brindle
# 31171           3 years  Rat Terrier Mix  Tricolor/Brown Brindle
# 19668           4 years  Rat Terrier Mix  Tricolor/Brown Brindle
# 139867          3 years  Rat Terrier Mix  Tricolor/Brown Brindle
# 69402            1 year  Rat Terrier Mix  Tricolor/Brown Brindle
# 69340           3 years  Rat Terrier Mix  Tricolor/Brown Brindle
# 4949            4 years  Rat Terrier Mix  Tricolor/Brown Brindle
# 42872           3 years  Rat Terrier Mix  Tricolor/Brown Brindle
# 88456           3 years  Rat Terrier Mix  Tricolor/Brown Brindle
# 99620            1 year  Rat Terrier Mix  Tricolor/Brown Brindle
# 68092           4 years  Rat Terrier Mix  Tricolor/Brown Brindle
# 83424           3 years  Rat Terrier Mix  Tricolor/Brown Brindle
# 54887           3 years  Rat Terrier Mix  Tricolor/Brown Brindle
# 73224           4 years  Rat Terrier Mix  Tricolor/Brown Brindle
# 13829            1 year  Rat Terrier Mix  Tricolor/Brown Brindle
# 24355           3 years  Rat Terrier Mix  Tricolor/Brown Brindle
# 98239            1 year  Rat Terrier Mix  Tricolor/Brown Brindle
# 94443           3 years  Rat Terrier Mix  Tricolor/Brown Brindle

# %%
#To merge the intake and outcome datasets while keeping the multiple-visit pets in the set, I will group by Animal ID to assign each visit a count, combine the Animal ID with the count, and merge along this key
#First I want to sort the datasets by DateTime, which means my current DateTime str needs to be convert to a numerical. 
intake_data_raw['DateTime'] = pd.to_datetime(intake_data_raw['DateTime'], format = '%m/%d/%Y %H:%M:%S %p')
outcome_data_raw['DateTime'] = pd.to_datetime(outcome_data_raw['DateTime'], format = '%m/%d/%Y %H:%M:%S %p')

# %%
#Sorting the datasets by DateTime and dropping rows that have the same Animal ID & DateTime (ie. true duplicate entries)
intake_data_raw.sort_values(by = 'DateTime')
intake_data_raw['Duplicated?'] = intake_data_raw.duplicated(subset=['Animal ID', 'DateTime'])

outcome_data_raw.sort_values(by = 'DateTime')
outcome_data_raw['Duplicated?'] = outcome_data_raw.duplicated(subset=['Animal ID', 'DateTime'])

# %%
#Spotchecking that duplicates that were flagged are true duplicates and not repeat visits and checking the length of each to see how many were dropped. 
#It worked =)

#outcome_data_raw.loc[outcome_data_raw['Duplicated?'] == True] #25 count
#intake_data_raw.loc[intake_data_raw['Duplicated?'] == True] #37 count
#intake_data_raw.loc[intake_data_raw['Animal ID'] == 'A727043']
# Out:
#        Animal ID        Name            DateTime       MonthYear  \
# 4900     A830075      Waffle 2021-03-02 01:35:00      March 2021
# 7022     A696688        Mari 2015-02-10 11:00:00   February 2015
# 9206     A727043      *Larry 2016-05-17 03:46:00        May 2016
# 13264    A866229      *Jones 2022-09-26 03:17:00  September 2022
# 13977    A761936         NaN 2017-11-12 11:16:00   November 2017
# 15336    A863452       Amber 2022-08-31 11:55:00     August 2022
# 18221    A561806       Dasia 2017-06-05 11:36:00       June 2017
# 30514    A773428     *Atreyu 2018-05-31 06:38:00        May 2018
# 49996    A815987    Princess 2020-04-09 03:32:00      April 2020
# 52864    A876931         NaN 2023-03-22 06:14:00      March 2023
# 53527    A735395         Owl 2016-09-23 12:00:00  September 2016
# 62890    A698864         NaN 2015-03-19 01:37:00      March 2015
# 67611    A668183       Nacha 2014-06-27 11:34:00       June 2014
# 68968    A681446         NaN 2014-06-16 04:38:00       June 2014
# 69538    A764464      Pepper 2018-09-17 03:09:00  September 2018
# 71275    A814983        Flor 2021-06-08 03:37:00       June 2021
# 73639    A695798         Jim 2015-01-23 11:48:00    January 2015
# 83570    A797007        Ummi 2019-06-08 12:03:00       June 2019
# 85590    A748204         Bob 2017-04-30 04:24:00      April 2017
# 91917    A873909   *Titanium 2023-02-02 02:38:00   February 2023
# 97455    A846569     A846569 2021-11-17 02:58:00   November 2021
# 104492   A851208       Maisy 2022-02-08 03:36:00   February 2022
# 104833   A811566       Bubby 2020-07-19 10:01:00       July 2020
# 120828   A719747       Layla 2021-02-12 09:51:00   February 2021
# 127461   A672744         Oso 2014-02-17 05:10:00   February 2014
# 129041   A782931        Mika 2018-10-23 12:29:00    October 2018
# 131078   A811566       Bubby 2020-01-05 09:13:00    January 2020
# 132455   A755687         NaN 2017-08-07 12:39:00     August 2017
# 134985   A833777     *Ripple 2021-05-05 01:08:00        May 2021
# 140965   A860875       *Crow 2022-07-05 11:26:00       July 2022
# 147704   A877714      *Froyo 2023-03-31 05:00:00      March 2023
# 149407   A857222       Keanu 2022-05-13 01:58:00        May 2022
# 152781   A783234    Princess 2018-11-01 02:36:00   November 2018
# 156790   A887327         NaN 2023-08-18 06:20:00     August 2023
# 158655   A874763      Oolong 2023-05-22 04:29:00        May 2023
# 159532   A862948  *Christine 2022-08-02 02:53:00     August 2022
# 160491   A826102       Sasha 2020-11-19 11:13:00   November 2020
#
#                                         Found Location      Intake Type  \
# 4900    Onion Creek And Pleasant Valley in Austin (TX)            Stray
# 7022                                       Austin (TX)  Owner Surrender
# 9206                  9515 N Lamar Blvd in Austin (TX)            Stray
# 13264                   9301 Hog Eye Rd in Austin (TX)            Stray
# 13977                8400 Old Bee Caves in Austin (TX)            Stray
# 15336                    4200 Brookview in Austin (TX)            Stray
# 18221                    2002 Nightview in Austin (TX)            Stray
# 30514                  7Th And Gonzalez in Austin (TX)            Stray
# 49996                                      Austin (TX)    Public Assist
# 52864                  15 Waller Street in Austin (TX)         Wildlife
# 53527                                      Austin (TX)  Owner Surrender
# 62890                    12129 Glass Rd in Travis (TX)         Wildlife
# 67611                                      Austin (TX)    Public Assist
# 68968                    6208 Tupelo Dr in Austin (TX)         Wildlife
# 69538                                   Del Valle (TX)  Owner Surrender
# 71275                    1500 Parkfield in Austin (TX)            Stray
# 73639                                      Austin (TX)  Owner Surrender
# 83570                                      Austin (TX)  Owner Surrender
# 85590                                      Austin (TX)  Owner Surrender
# 91917      Pierce Lane And Timber Hills in Travis (TX)            Stray
# 97455     Colfax And Blazewood Crossing in Austin (TX)            Stray
# 104492                                     Travis (TX)  Owner Surrender
# 104833             507 South 1St Street in Austin (TX)    Public Assist
# 120828                 12 St And Brazos in Austin (TX)            Stray
# 127461                                     Travis (TX)  Owner Surrender
# 129041            13309 Slow Poke Drive in Austin (TX)            Stray
# 131078        507 South !St Street #244 in Austin (TX)    Public Assist
# 132455              505  Barton Springs in Austin (TX)         Wildlife
# 134985                                     Austin (TX)  Owner Surrender
# 140965                            Outside Jurisdiction  Owner Surrender
# 147704                                     Austin (TX)  Owner Surrender
# 149407                     1800 S Ih 35 in Austin (TX)  Owner Surrender
# 152781                                     Austin (TX)    Public Assist
# 156790                                     Austin (TX)  Owner Surrender
# 158655                                     Austin (TX)  Owner Surrender
# 159532               5008 Burleson Road in Austin (TX)  Owner Surrender
# 160491                                     Austin (TX)  Owner Surrender
#
#        Intake Condition Animal Type Sex upon Intake Age upon Intake  \
# 4900             Normal         Dog     Intact Male          1 year
# 7022             Normal         Cat   Spayed Female         3 years
# 9206             Normal         Cat     Intact Male          1 year
# 13264            Normal         Cat     Intact Male         1 month
# 13977            Normal         Dog     Intact Male        9 months
# 15336            Normal         Dog   Intact Female       10 months
# 18221            Normal         Dog   Spayed Female         8 years
# 30514            Normal         Cat     Intact Male         3 weeks
# 49996            Normal         Dog   Intact Female          1 year
# 52864            Normal       Other         Unknown          1 year
# 53527            Normal         Cat   Intact Female       10 months
# 62890           Injured       Other         Unknown          1 year
# 67611            Normal         Dog   Spayed Female       10 months
# 68968            Normal       Other         Unknown          1 year
# 69538            Normal         Dog   Spayed Female       11 months
# 71275           Injured         Dog   Intact Female         5 years
# 73639              Sick         Cat   Neutered Male       10 months
# 83570              Sick         Dog   Neutered Male         9 years
# 85590            Normal         Cat     Intact Male        2 months
# 91917            Normal         Dog     Intact Male         4 weeks
# 97455           Injured         Dog     Intact Male        5 months
# 104492           Normal         Dog   Intact Female         4 years
# 104833           Normal         Cat   Neutered Male         2 years
# 120828           Normal         Dog   Spayed Female         5 years
# 127461           Normal         Dog     Intact Male         3 years
# 129041           Normal         Cat   Spayed Female          1 year
# 131078           Normal         Cat   Neutered Male          1 year
# 132455           Normal       Other         Unknown         3 years
# 134985           Normal         Cat   Intact Female         3 weeks
# 140965           Normal         Cat   Intact Female        4 months
# 147704           Normal         Dog   Intact Female         2 years
# 149407           Normal       Other     Intact Male        8 months
# 152781           Normal         Dog   Intact Female         2 years
# 156790           Normal         Cat   Intact Female        3 months
# 158655           Normal         Dog   Neutered Male         3 years
# 159532           Normal         Cat   Intact Female        3 months
# 160491           Normal         Dog   Intact Female         2 years
#
#                                   Breed                Color  Duplicated?
# 4900            Chihuahua Shorthair Mix                  Tan         True
# 7022             Domestic Shorthair Mix         Calico/White         True
# 9206             Domestic Shorthair Mix           Blue/White         True
# 13264                Domestic Shorthair         Orange Tabby         True
# 13977              Scottish Terrier Mix        Brown Brindle         True
# 15336                   German Shepherd                White         True
# 18221                      Pit Bull Mix  Brown Brindle/White         True
# 30514            Domestic Shorthair Mix         Orange Tabby         True
# 49996                     Cairn Terrier          White/Brown         True
# 52864                               Bat                Brown         True
# 53527            Domestic Shorthair Mix          Brown Tabby         True
# 62890                         Skunk Mix                Black         True
# 67611                     Dachshund Mix          Black/White         True
# 68968                               Bat                Brown         True
# 69538   Soft Coated Wheaten Terrier Mix       Black/Tricolor         True
# 71275              Pembroke Welsh Corgi         White/Yellow         True
# 73639            Domestic Shorthair Mix               Orange         True
# 83570                  Miniature Poodle                White         True
# 85590            Domestic Shorthair Mix           White/Blue         True
# 91917            Labrador Retriever Mix            Black/Tan         True
# 97455         Australian Cattle Dog Mix             Red Tick         True
# 104492                     Pit Bull Mix           Fawn/White         True
# 104833               Domestic Shorthair                White         True
# 120828    American Pit Bull Terrier Mix          White/Brown         True
# 127461                   Rottweiler Mix            Black/Tan         True
# 129041           Domestic Shorthair Mix               Tortie         True
# 131078               Domestic Shorthair                White         True
# 132455                          Bat Mix                Brown         True
# 134985           Domestic Shorthair Mix               Calico         True
# 140965               Domestic Shorthair         Calico/White         True
# 147704                  German Shepherd          Brown/Black         True
# 149407                       Guinea Pig           White/Gray         True
# 152781            Collie Smooth/Pointer                Brown         True
# 156790             Domestic Medium Hair    Brown Tabby/White         True
# 158655                      Plott Hound          Black/Brown         True
# 159532           Domestic Shorthair Mix          Brown Tabby         True
# 160491               Siberian Husky Mix       Black/Tricolor         True

# %%
outcome_data_raw = outcome_data_raw.loc[outcome_data_raw['Duplicated?'] != True]
#len(outcome_data_raw) #164203 length

intake_data_raw = intake_data_raw.loc[intake_data_raw['Duplicated?'] != True]
#len(intake_data_raw) #164577 length
# Out:
# 164577

# %% [markdown]
# ### Merging intake & outcome data sets

# %%
#Group both datasets by Animal ID & use the cumulative count to organize repeat visits 
intake_data_raw['Visit Count'] = intake_data_raw.groupby(by = 'Animal ID').cumcount() +1
outcome_data_raw['Visit Count'] = outcome_data_raw.groupby(by = 'Animal ID').cumcount() +1

# %%
# Merge the intake and outcome data sets based on Animal ID and Visit Count
merged_data_raw = pd.merge(intake_data_raw, outcome_data_raw, on = ['Animal ID', 'Visit Count'])
len(outcome_data_raw) - len(merged_data_raw)
#len(merged_data_raw) #163263
#I expected the outcome data length to be longer than the merged data length because some pets will not have both intake and outcome data, and so would not be included in the merged set
# Out:
# 940

# %%
#When I examine the animals that did not make it into the merged set from the outcome data, most of them are from the time the shelter first started recording data (Oct 1, 2013). 
#Pets admitted prior to this date, would not have intake data to match with their outcome data, so they cannot be included. 
#There are a few pets from later on that are also missing intake data for some reason. None of these pets have multiple visits, so they will not mess up the merged data set. 

outcome_data_not_merged = outcome_data_raw[~outcome_data_raw['Animal ID'].isin(merged_data_raw['Animal ID'])]
outcome_data_not_merged.loc[outcome_data_not_merged['Visit Count'] > 1]
# Out:
# Empty DataFrame
# Columns: [Animal ID, Name, DateTime, MonthYear, Date of Birth, Outcome Type, Outcome Subtype, Animal Type, Sex upon Outcome, Age upon Outcome, Breed, Color, Duplicated?, Visit Count]
# Index: []

# %%
#When I examine the animals that did not make it into the merged set from the intake data, almost all of them (1116/1189) are from 2024, so there is a good chance, these pets do not yet have outcomes.
#Of the smaller number of animals that predate 2024, none of them have outcome data. They can be considered "lost" and excluded from the data set

intake_data_not_merged = intake_data_raw[~intake_data_raw['Animal ID'].isin(merged_data_raw['Animal ID'])]
#intake_data_not_merged.loc[intake_data_not_merged['DateTime'] >= '2024'].sort_values(by = 'DateTime')
#intake_data_not_merged.loc[intake_data_not_merged['DateTime'] < '2023'].sort_values(by = 'DateTime')
#intake_data_not_merged.loc[intake_data_not_merged['Visit Count'] > 1]
# Out:
#        Animal ID             Name            DateTime       MonthYear  \
# 5597     A636629              NaN 2014-09-07 04:31:00  September 2014
#
#                                                Breed              Color  \
# 5597                          Domestic Shorthair Mix             Tortie
# 33381                          Domestic Longhair Mix  Cream Tabby/White
# 157212                     Pit Bull/Golden Retriever        White/Black
# 41482                                       Pit Bull        Brown/White
# 40691                         Labrador Retriever Mix              Black
# 25264                                       Pit Bull      Brown Brindle
# 156359                     American Pit Bull Terrier        Black/White
# 55367                                       Pit Bull        Black/White
# 160722  American Pit Bull Terrier/Labrador Retriever        Black/White
# 55962                                       Pit Bull               Blue
# 150807                                   Bulldog Mix         Blue Cream
# 60588             Anatol Shepherd/Labrador Retriever        White/Brown
# 112041                                  Pit Bull Mix        Black/White
# 152064                            Domestic Shorthair        Brown Tabby
# 5430                       American Pit Bull Terrier        White/Black
# 134257                            Domestic Shorthair         Blue Tabby
# 154416                                      Pit Bull    Chocolate/White
# 42162                                   Pit Bull Mix         Fawn/White
#
#         Duplicated?  Visit Count
# 5597          False            1
# 33381         False            1
# 157212        False            1
# 41482         False            1
# 40691         False            1
# 25264         False            1
# 156359        False            1
# 55367         False            1
# 160722        False            1
# 55962         False            1
# 150807        False            1
# 60588         False            1
# 112041        False            1
# 152064        False            1
# 5430          False            1
# 134257        False            1
# 154416        False            1
# 42162         False            1

# %% [markdown]
# ### Cleaning the merged data set - Nulls

# %%
merged_data_raw.columns
# Looking at the columns of the merged data set, there are several columns that should be identical (ex. Breed_x & Breed_y),
# some columns are redundant (monthyear), and some are not helpful (Duplicated?)
# Out:
# Index(['Animal ID', 'Name_x', 'DateTime_x', 'MonthYear_x', 'Found Location',
#        'Intake Type', 'Intake Condition', 'Animal Type_x', 'Sex upon Intake',
#        'Age upon Intake', 'Breed_x', 'Color_x', 'Duplicated?_x', 'Visit Count',
#        'Name_y', 'DateTime_y', 'MonthYear_y', 'Date of Birth', 'Outcome Type',
#        'Outcome Subtype', 'Animal Type_y', 'Sex upon Outcome',
#        'Age upon Outcome', 'Breed_y', 'Color_y', 'Duplicated?_y'],
#       dtype='object')

# %%
#First I will make sure that the columns that should be identical actually are.

# merged_data_raw.loc[(merged_data_raw['Breed_x'] == merged_data_raw['Breed_y']) == False] 
# merged_data_raw.loc[(merged_data_raw['Animal Type_x'] == merged_data_raw['Animal Type_y']) == False]
merged_data_raw.loc[(merged_data_raw['Color_x'] == merged_data_raw['Color_y']) == False]
# Out:
# Empty DataFrame
# Columns: [Animal ID, Name_x, DateTime_x, MonthYear_x, Found Location, Intake Type, Intake Condition, Animal Type_x, Sex upon Intake, Age upon Intake, Breed_x, Color_x, Duplicated?_x, Visit Count, Name_y, DateTime_y, MonthYear_y, Date of Birth, Outcome Type, Outcome Subtype, Animal Type_y, Sex upon Outcome, Age upon Outcome, Breed_y, Color_y, Duplicated?_y]
# Index: []
#
# [0 rows x 26 columns]

# %%
# Since all of those duplicate columns matched like they should, I can drop the duplicates without issue. 
# I will also drop the sensitive, redundant, and not helpful data. 

merged_data = merged_data_raw.drop(['Name_x', 'MonthYear_x', 'Found Location', 'Duplicated?_x', 'Name_y', 'MonthYear_y', 'Animal Type_y', 'Breed_y', 'Color_y', 'Duplicated?_y'], axis = 1)
merged_data.head()
# Out:
#   Animal ID          DateTime_x    Intake Type Intake Condition Animal Type_x  \
# 0   A786884 2019-01-03 04:19:00          Stray           Normal           Dog
# 1   A706918 2015-07-05 12:59:00          Stray           Normal           Dog
# 2   A724273 2016-04-14 06:43:00          Stray           Normal           Dog
# 3   A857105 2022-05-12 12:23:00  Public Assist           Normal           Cat
# 4   A682524 2014-06-29 10:38:00          Stray           Normal           Dog
#
#   Sex upon Intake Age upon Intake                                Breed_x  \
# 0   Neutered Male         2 years                             Beagle Mix
# 1   Spayed Female         8 years               English Springer Spaniel
# 2     Intact Male       11 months                            Basenji Mix
# 3   Neutered Male         2 years                     Domestic Shorthair
# 4   Neutered Male         4 years  Doberman Pinsch/Australian Cattle Dog
#
#         Color_x  Visit Count          DateTime_y Date of Birth  \
# 0      Tricolor            1 2019-01-08 03:11:00    01/03/2017
# 1   White/Liver            1 2015-07-05 03:13:00    07/05/2007
# 2   Sable/White            1 2016-04-21 05:17:00    04/17/2015
# 3  Orange Tabby            1 2022-05-12 02:35:00    05/12/2020
# 4      Tan/Gray            1 2014-07-02 02:16:00    06/29/2010
#
#       Outcome Type Outcome Subtype Sex upon Outcome Age upon Outcome
# 0         Transfer         Partner    Neutered Male          2 years
# 1  Return to Owner             NaN    Spayed Female          8 years
# 2  Return to Owner             NaN    Neutered Male           1 year
# 3         Transfer         Partner    Neutered Male          2 years
# 4  Return to Owner             NaN    Neutered Male          4 years

# %%
# And renaming some columns to improve organization. 
merged_data = merged_data.rename({'DateTime_x': 'Intake DateTime', 'Animal Type_x': 'Animal Type', 'Breed_x': 'Breed', 'Color_x':'Color', 'DateTime_y': 'Outcome DateTime'}, axis='columns')
merged_data = merged_data.reindex(columns = ['Animal ID', 'Animal Type', 'Date of Birth', 'Breed', 'Color', 'Intake Type', 'Intake Condition', 'Sex upon Intake', 'Age upon Intake', 'Intake DateTime', 'Outcome DateTime', 'Outcome Type', 'Outcome Subtype', 'Sex upon Outcome', 'Age upon Outcome'])
merged_data.head()
# Out:
#   Animal ID Animal Type Date of Birth                                  Breed  \
# 0   A786884         Dog    01/03/2017                             Beagle Mix
# 1   A706918         Dog    07/05/2007               English Springer Spaniel
# 2   A724273         Dog    04/17/2015                            Basenji Mix
# 3   A857105         Cat    05/12/2020                     Domestic Shorthair
# 4   A682524         Dog    06/29/2010  Doberman Pinsch/Australian Cattle Dog
#
#           Color    Intake Type Intake Condition Sex upon Intake  \
# 0      Tricolor          Stray           Normal   Neutered Male
# 1   White/Liver          Stray           Normal   Spayed Female
# 2   Sable/White          Stray           Normal     Intact Male
# 3  Orange Tabby  Public Assist           Normal   Neutered Male
# 4      Tan/Gray          Stray           Normal   Neutered Male
#
#   Age upon Intake     Intake DateTime    Outcome DateTime     Outcome Type  \
# 0         2 years 2019-01-03 04:19:00 2019-01-08 03:11:00         Transfer
# 1         8 years 2015-07-05 12:59:00 2015-07-05 03:13:00  Return to Owner
# 2       11 months 2016-04-14 06:43:00 2016-04-21 05:17:00  Return to Owner
# 3         2 years 2022-05-12 12:23:00 2022-05-12 02:35:00         Transfer
# 4         4 years 2014-06-29 10:38:00 2014-07-02 02:16:00  Return to Owner
#
#   Outcome Subtype Sex upon Outcome Age upon Outcome
# 0         Partner    Neutered Male          2 years
# 1             NaN    Spayed Female          8 years
# 2             NaN    Neutered Male           1 year
# 3         Partner    Neutered Male          2 years
# 4             NaN    Neutered Male          4 years

# %%
merged_data.describe(include = 'all')
# The data set contains over 160k animals. All of this information could potentially effect outcome (adoption vs other).
# There is still some redundant information between "age upon intake," "Date of Birth," and "age upon outcome," but we can address this later
# Out:
#        Animal ID Animal Type Date of Birth                   Breed  \
# count     163263      163263        163263                  163263
# unique    146673           5          8378                    2936
# top      A721033         Dog    05/01/2016  Domestic Shorthair Mix
# freq          33       89841           121                   33443
# mean         NaN         NaN           NaN                     NaN
# min          NaN         NaN           NaN                     NaN
# 25%          NaN         NaN           NaN                     NaN
# 50%          NaN         NaN           NaN                     NaN
# 75%          NaN         NaN           NaN                     NaN
# max          NaN         NaN           NaN                     NaN
#
#               Color Intake Type Intake Condition Sex upon Intake  \
# count        163263      163263           163263          163261
# unique          648           6               20               5
# top     Black/White       Stray           Normal     Intact Male
# freq          16987      111908           139064           55043
# mean            NaN         NaN              NaN             NaN
# min             NaN         NaN              NaN             NaN
# 25%             NaN         NaN              NaN             NaN
# 50%             NaN         NaN              NaN             NaN
# 75%             NaN         NaN              NaN             NaN
# max             NaN         NaN              NaN             NaN
#
#        Age upon Intake                Intake DateTime  \
# count           163262                         163263
# unique              55                            NaN
# top             1 year                            NaN
# freq             26855                            NaN
# mean               NaN  2018-07-13 17:37:30.555116800
# min                NaN            2013-10-01 01:12:00
# 25%                NaN            2015-12-11 09:18:30
# 50%                NaN            2018-04-30 11:41:00
# 75%                NaN            2020-12-02 02:56:30
# max                NaN            2024-06-30 01:24:00
#
#                      Outcome DateTime Outcome Type Outcome Subtype  \
# count                          163263       163226           74974
# unique                            NaN           11              26
# top                               NaN     Adoption         Partner
# freq                              NaN        77874           38548
# mean    2018-08-02 18:15:03.282923776          NaN             NaN
# min               2013-10-01 01:00:00          NaN             NaN
# 25%               2016-01-02 02:18:00          NaN             NaN
# 50%               2018-05-17 12:26:00          NaN             NaN
# 75%               2021-01-04 08:35:30          NaN             NaN
# max               2024-07-01 11:15:00          NaN             NaN
#
#        Sex upon Outcome Age upon Outcome
# count            163261           163253
# unique                5               55
# top       Neutered Male           1 year
# freq              57065            27309
# mean                NaN              NaN
# min                 NaN              NaN
# 25%                 NaN              NaN
# 50%                 NaN              NaN
# 75%                 NaN              NaN
# max                 NaN              NaN

# %%
merged_data.isnull().sum()
# There are a number of null values throughout the data set, 
# The "outcome subtype" is the largest cluster because not every Outcome Type needs to be further described by a Subtype
# Options for handling the subtype nulls include: 
#      marking the nulls as "None" or similar placeholder, 
#      dropping the subtype variable altogether, 
#      combining the type-subtype data into one variable. 
# For now, I will mark the Nan Subtypes as None, but I might circle back to this later.
# Out:
# Animal ID               0
# Animal Type             0
# Date of Birth           0
# Breed                   0
# Color                   0
# Intake Type             0
# Intake Condition        0
# Sex upon Intake         2
# Age upon Intake         1
# Intake DateTime         0
# Outcome DateTime        0
# Outcome Type           37
# Outcome Subtype     88289
# Sex upon Outcome        2
# Age upon Outcome       10
# dtype: int64

# %%
merged_data['Outcome Subtype'] = merged_data['Outcome Subtype'].fillna(value = 'None')
# Out:
# C:\Users\wisery\AppData\Local\Temp\ipykernel_132400\3830609047.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_data['Outcome Subtype'] = merged_data['Outcome Subtype'].fillna(value = 'None')

# %%
merged_data.loc[merged_data['Outcome Type'].isnull() == True]

# There are a few pets that have no recorded Outcome type, and these can't help answer my questions about what gets pets adopted, so I will drop them. 

merged_data = merged_data.loc[merged_data['Outcome Type'].isnull() != True]

# %%
merged_data = merged_data.loc[merged_data['Sex upon Outcome'].isnull() != True]

# %%
merged_data.loc[merged_data['Age upon Outcome'].isnull() == True]

# There are a few pets that have no recorded age or sex upon outcome. 
# For a couple of these, they have an "age upon intake," so "age upon outcome" 
# can easily be calculated and filled in, but because my data set is large, I'm going to drop these. 

merged_data = merged_data.dropna(subset = ['Age upon Outcome'], axis = 0)

#merged_data = merged_data.loc[merged_data['Age upon Outcome'].isnull() != True &
#                             merged_data['Sex upon Outcome'].isnull() !=]
# Out:
# C:\Users\wisery\AppData\Local\Temp\ipykernel_132400\723133318.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   merged_data['Age upon Outcome'][162151] = '1 year'
# C:\Users\wisery\AppData\Local\Temp\ipykernel_132400\723133318.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_data['Age upon Outcome'][162151] = '1 year'

# %%
merged_data.isnull().sum()
# Out:
# Animal ID           0
# Animal Type         0
# Date of Birth       0
# Breed               0
# Color               0
# Intake Type         0
# Intake Condition    0
# Sex upon Intake     0
# Age upon Intake     0
# Intake DateTime     0
# Outcome DateTime    0
# Outcome Type        0
# Outcome Subtype     0
# Sex upon Outcome    0
# Age upon Outcome    0
# dtype: int64

# %%
# Since I hope this data analysis can be repeated on updated data in the future, I put the above
# null management sequence into a method that can go in a module

def drop_null_data(df):
    #identifies null data in provided data frame, drops it, and reports columns in which the data were null

    #generates a Series with index = df's columns, values = number of nulls per column
    drops = df.isnull().sum()

    #if there are no nulls in the df, print & return original df
    if drops.sum() == 0:
        print("No null values identified")
            
    #if there are nulls in the df, drop them all and print which columns contained nulls and how many were dropped; returns df without nulls    
    else:
        df = df.dropna(axis = 0)
        for index, value in drops.items():
            if value != 0:
                print('"{}" contained {} null value(s)'.format(index, value))
    return df

# %% [markdown]
# ### Cleaning the merged data set - Sanity Checks

# %% [markdown]
# ##### Ages - Neonates & Aged

# %%
# The data contains a small number of animals that have ages listed as negative numbers. 
# They are few enough that I could drop them, but I prefer to fix them. 

merged_data['Age upon Intake'].unique()
# Out:
# array(['2 years', '8 years', '11 months', '4 years', '4 months',
#        '6 years', '6 months', '4 weeks', '5 months', '14 years',
#        '1 month', '2 months', '18 years', '3 years', '1 year', '4 days',
#        '9 years', '2 weeks', '15 years', '1 day', '5 years', '3 weeks',
#        '9 months', '8 months', '6 days', '7 years', '12 years', '1 week',
#        '10 years', '7 months', '3 months', '10 months', '1 weeks',
#        '5 days', '2 days', '0 years', '11 years', '17 years', '3 days',
#        '13 years', '5 weeks', '19 years', '16 years', '20 years',
#        '-1 years', '22 years', '28 years', '23 years', '30 years',
#        '-2 years', '21 years', '-3 years', '25 years', '24 years',
#        '-4 years'], dtype=object)

# %%
# This method will use regex to convert the ages from strings to ints
# I leave the ages in days because the computer doesn't need years/months/weeks/days to draw conclusions, 
# but for data visualization later, they will need to be converted to more meaningful numbers.

import re

year_pattern = re.compile(r"(-?\d+)\s*(?:year|years)")
month_pattern = re.compile(r"(-?\d+)\s*(?:month|months)")
week_pattern = re.compile(r"(-?\d+)\s*(?:week|weeks)")
day_pattern = re.compile(r"(-?\d+)\s*(?:day|days)")

# Function to convert strings to days
def convert_to_days(age_str):
    if "year" in age_str:
        value = re.search(year_pattern, age_str).group(1)
        return int(value) * 365
    elif "month" in age_str:
        value = re.search(month_pattern, age_str).group(1)
        return int(value) * 30 
    elif "week" in age_str:
        value = re.search(week_pattern, age_str).group(1)
        return int(value) * 7
    elif "day" in age_str:
        value = re.search(day_pattern, age_str).group(1)
        return int(value)
    else:
        print(f"Unknown pattern: {age_str}; -1 days reported")
        return int(-1)

# %%
merged_data['Age upon Intake'] = merged_data['Age upon Intake'].apply(convert_to_days)
merged_data['Age upon Outcome'] = merged_data['Age upon Outcome'].apply(convert_to_days)
merged_data.head()
# Out:
#   Animal ID Animal Type Date of Birth                                  Breed  \
# 0   A786884         Dog    01/03/2017                             Beagle Mix
# 1   A706918         Dog    07/05/2007               English Springer Spaniel
# 2   A724273         Dog    04/17/2015                            Basenji Mix
# 3   A857105         Cat    05/12/2020                     Domestic Shorthair
# 4   A682524         Dog    06/29/2010  Doberman Pinsch/Australian Cattle Dog
#
#           Color    Intake Type Intake Condition Sex upon Intake  \
# 0      Tricolor          Stray           Normal   Neutered Male
# 1   White/Liver          Stray           Normal   Spayed Female
# 2   Sable/White          Stray           Normal     Intact Male
# 3  Orange Tabby  Public Assist           Normal   Neutered Male
# 4      Tan/Gray          Stray           Normal   Neutered Male
#
#    Age upon Intake     Intake DateTime    Outcome DateTime     Outcome Type  \
# 0              730 2019-01-03 04:19:00 2019-01-08 03:11:00         Transfer
# 1             2920 2015-07-05 12:59:00 2015-07-05 03:13:00  Return to Owner
# 2              330 2016-04-14 06:43:00 2016-04-21 05:17:00  Return to Owner
# 3              730 2022-05-12 12:23:00 2022-05-12 02:35:00         Transfer
# 4             1460 2014-06-29 10:38:00 2014-07-02 02:16:00  Return to Owner
#
#   Outcome Subtype Sex upon Outcome  Age upon Outcome
# 0         Partner    Neutered Male               730
# 1            None    Spayed Female              2920
# 2            None    Neutered Male               365
# 3         Partner    Neutered Male               730
# 4            None    Neutered Male              1460

# %%
# Dropping rows with negative ages for both Age upon Intake & Age upon Outcome

pre = len(merged_data)
merged_data = merged_data.loc[merged_data['Age upon Intake'] >= 0]
post= len(merged_data)
print(f"Dropped rows due to negative Intake ages: {pre - post}")

pre2 = len(merged_data)
merged_data = merged_data.loc[merged_data['Age upon Outcome'] >= 0]
post2 = len(merged_data)
print(f"Dropped rows due to negative Outcome ages: {pre - post}")
# Out:
# Dropped rows due to negative Intake ages: 0
# Dropped rows due to negative Outcome ages: 0

# %%
merged_data.head()
# Out:
#   Animal ID Animal Type Date of Birth                                  Breed  \
# 0   A786884         Dog    01/03/2017                             Beagle Mix
# 1   A706918         Dog    07/05/2007               English Springer Spaniel
# 2   A724273         Dog    04/17/2015                            Basenji Mix
# 3   A857105         Cat    05/12/2020                     Domestic Shorthair
# 4   A682524         Dog    06/29/2010  Doberman Pinsch/Australian Cattle Dog
#
#           Color    Intake Type Intake Condition Sex upon Intake  \
# 0      Tricolor          Stray           Normal   Neutered Male
# 1   White/Liver          Stray           Normal   Spayed Female
# 2   Sable/White          Stray           Normal     Intact Male
# 3  Orange Tabby  Public Assist           Normal   Neutered Male
# 4      Tan/Gray          Stray           Normal   Neutered Male
#
#    Age upon Intake     Intake DateTime    Outcome DateTime     Outcome Type  \
# 0              730 2019-01-03 04:19:00 2019-01-08 03:11:00         Transfer
# 1             2920 2015-07-05 12:59:00 2015-07-05 03:13:00  Return to Owner
# 2              330 2016-04-14 06:43:00 2016-04-21 05:17:00  Return to Owner
# 3              730 2022-05-12 12:23:00 2022-05-12 02:35:00         Transfer
# 4             1460 2014-06-29 10:38:00 2014-07-02 02:16:00  Return to Owner
#
#   Outcome Subtype Sex upon Outcome  Age upon Outcome
# 0         Partner    Neutered Male               730
# 1            None    Spayed Female              2920
# 2            None    Neutered Male               365
# 3         Partner    Neutered Male               730
# 4            None    Neutered Male              1460

# %%
merged_data['Intake Condition'].value_counts()

# These are the identifier & counts for the intake condition column. Some are very large & some are only single animals.
# I would ulimately like to consolidate these, but first, I would like to do some checking to make sure they are accurate.
# For example, a neonate should not be an old animal, and a pet described as "aged" should not be young. 
# Pregnant and nursing animals should be female.
# Out:
# Intake Condition
# Normal        135694
# Injured         8688
# Sick            5524
# Nursing         3821
# Neonatal        1413
# Aged             466
# Medical          370
# Other            338
# Pregnant         148
# Feral            139
# Behavior          69
# Med Attn          52
# Unknown           12
# Med Urgent        11
# Neurologic         9
# Parvo              5
# Space              4
# Agonal             3
# Congenital         1
# Panleuk            1
# Name: count, dtype: int64

# %%
merged_data.loc[merged_data['Intake Condition'] == 'Neonatal'].sort_values(by = 'Age upon Intake', ascending = False)

# There are 2 year old animals being called "neonates," so that's not correct. Medically speaking, puppies/kittens are considered neonates when they're younger than 14 days (28 if you're lenient).
# I will drop any animals that are considered "neonatal" with an age upon intake <30 days.
# Out:
#        Animal ID Animal Type Date of Birth                    Breed  \
# 72672    A841441         Dog    08/27/2019        Queensland Heeler
# 162112   A908186         Cat    06/26/2022       Domestic Shorthair
# 63820    A845043         Cat    10/25/2019       Domestic Shorthair
# 55242    A845299         Cat    10/27/2019       Domestic Shorthair
# 141172   A843380         Dog    09/30/2019      Chihuahua Shorthair
# ...          ...         ...           ...                      ...
# 26520    A868023         Cat    10/27/2022       Domestic Shorthair
# 153074   A891067         Cat    10/16/2023       Domestic Shorthair
# 153073   A891065         Cat    10/16/2023       Domestic Shorthair
# 146354   A837039       Other    06/16/2021                Rabbit Sh
# 38795    A842247         Dog    09/12/2021  Chihuahua Shorthair Mix
#
#                     Color      Intake Type Intake Condition Sex upon Intake  \
# 72672                Blue            Stray         Neonatal   Spayed Female
# 162112             Calico            Stray         Neonatal   Intact Female
# 63820   Brown Tabby/White    Public Assist         Neonatal         Unknown
# 55242              Torbie        Abandoned         Neonatal   Intact Female
# 141172          Tan/White    Public Assist         Neonatal   Intact Female
# ...                   ...              ...              ...             ...
# 26520         Brown Tabby            Stray         Neonatal     Intact Male
# 153074        Brown Tabby  Owner Surrender         Neonatal   Intact Female
# 153073              White  Owner Surrender         Neonatal   Intact Female
# 146354              Black  Owner Surrender         Neonatal         Unknown
# 38795       Chocolate/Tan  Owner Surrender         Neonatal   Intact Female
#
#         Age upon Intake     Intake DateTime    Outcome DateTime  \
# 72672               730 2021-08-27 03:18:00 2021-09-29 06:59:00
# 162112              730 2024-06-26 11:18:00 2024-06-27 01:29:00
# 63820               730 2021-10-25 01:06:00 2021-10-27 01:16:00
# 55242               730 2021-10-27 05:24:00 2021-10-27 05:42:00
# 141172              730 2021-09-30 11:05:00 2022-01-18 03:33:00
# ...                 ...                 ...                 ...
# 26520                 0 2022-10-27 12:43:00 2022-10-27 03:52:00
# 153074                0 2023-10-16 12:05:00 2023-10-18 01:55:00
# 153073                0 2023-10-16 12:05:00 2023-10-18 01:29:00
# 146354                0 2021-06-16 01:03:00 2021-06-17 01:23:00
# 38795                 0 2021-09-12 02:11:00 2021-12-08 11:53:00
#
#            Outcome Type Outcome Subtype Sex upon Outcome  Age upon Outcome
# 72672          Adoption            None    Spayed Female               730
# 162112         Transfer         Partner    Intact Female               730
# 63820   Return to Owner            None          Unknown               730
# 55242          Transfer         Partner    Intact Female               730
# 141172  Return to Owner            None    Intact Female               730
# ...                 ...             ...              ...               ...
# 26520          Transfer         Partner      Intact Male                 0
# 153074         Transfer         Partner    Intact Female                 2
# 153073         Transfer         Partner    Intact Female                 2
# 146354         Transfer         Partner          Unknown                 1
# 38795          Adoption          Foster    Spayed Female                60
#
# [1413 rows x 15 columns]

# %%
merged_data.loc[(merged_data['Intake Condition'] == 'Aged') & (merged_data['Age upon Intake'] < 1460)].sort_values(by = 'Age upon Intake', ascending = True)

# There is no concrete ages at which an animal becomes "aged," and an animal who has had a hard life can appear "aged" before they are really old. 
# BUT there is no situation in which a 2 day old animal should be called "aged."
# I will be lenient and say any animal under 2yr shouldn't be in the "aged" category. This also allows for exotics, which have shorter lifespans.
# Out:
#        Animal ID Animal Type Date of Birth                   Breed  \
# 156375   A887830         Cat    08/25/2023      Domestic Shorthair
# 156374   A887829         Cat    08/25/2023      Domestic Shorthair
# 156376   A887831         Cat    08/25/2023      Domestic Shorthair
# 145208   A888924         Cat    09/12/2023      Domestic Shorthair
# 145210   A888923         Cat    09/12/2023      Domestic Shorthair
# 34980               730 2014-07-06 08:31:00 2014-07-07 09:00:00
# 161388              730 2023-09-23 04:31:00 2023-12-13 03:40:00
#
#            Outcome Type Outcome Subtype Sex upon Outcome  Age upon Outcome
# 156375         Transfer         Partner    Neutered Male                 2
# 156374         Transfer         Partner    Neutered Male                 2
# 156376         Transfer         Partner    Neutered Male                 2
# 145208         Transfer         Partner      Intact Male                 2
# 145210         Transfer         Partner    Intact Female                 2
# 143828         Transfer         Partner    Intact Female                 7
# 145212         Transfer         Partner    Intact Female                21
# 147771         Transfer         Partner      Intact Male                21
# 17775          Adoption          Foster    Neutered Male               180
# 54712          Adoption          Foster    Neutered Male               120
# 81243          Adoption            None    Neutered Male               180
# 108037         Adoption          Foster    Neutered Male               150
# 117524         Adoption          Foster    Spayed Female               120
# 147244         Adoption          Foster    Neutered Male                60
# 136617       Euthanasia       Suffering    Neutered Male               365
# 15325          Adoption            None    Spayed Female               730
# 27557   Return to Owner            None    Neutered Male               730
# 34980          Transfer            SCRP          Unknown               730
# 161388         Adoption            None    Spayed Female               730

# %%
#Sanity checked - no old "neonatal" or young "aged" animals
merged_data = merged_data[(merged_data['Intake Condition'] != 'Neonatal') |
                            (merged_data['Age upon Intake'] < 30)]

merged_data = merged_data[(merged_data['Intake Condition'] != 'Aged') |
                          (merged_data['Age upon Intake'] > 730)]

# %% [markdown]
# ##### Reproductive status - Pregnant & Nursing

# %%
merged_data.loc[(merged_data['Intake Condition'] == 'Pregnant') &
                (merged_data['Sex upon Intake'] != 'Intact Female')]

# There are a fair number of animals listed as pregnant that are male or spayed. 
# Since I can't trust this information, I will drop these ones too.
# Out:
#        Animal ID Animal Type Date of Birth  \
# 1571     A885138         Cat    07/14/2021
# 6181     A842769         Dog    10/06/2021
# 9187     A701482         Cat    04/30/2014
# 14285    A832146         Cat    04/08/2016
# 26326    A731134         Dog    07/17/2016
# 28138    A861113         Dog    06/07/2022
# 31384    A731133         Dog    07/17/2016
# 32694    A842777         Dog    09/18/2021
# 35022    A842775         Dog    09/18/2021
# 36791    A842773         Dog    09/18/2021
# 44440    A861112         Dog    06/07/2022
# 60185    A841407         Cat    08/27/2018
# 70622    A842770         Dog    09/18/2021
# 82574    A793977         Dog    05/02/2017
# 85121    A731136         Dog    07/17/2016
# 86344    A842771         Dog    09/18/2021
# 87767    A842772         Dog    09/18/2021
# 88622    A703551         Cat    05/26/2015
# 116099   A842776         Dog    09/18/2021
# 130103   A842200         Dog    09/11/2019
# 137866   A599849         Dog    12/12/2004
# 138615   A814697         Dog    03/04/2018
# 141821   A731138         Dog    07/17/2016
# 144911   A896109         Dog    11/14/2023
# 145394   A896111         Dog    11/14/2023
# 145773   A817504         Cat    06/26/2019
# 145786   A896112         Dog    11/14/2023
# 146149   A896110         Dog    11/14/2023
# 151285   A880187         Dog    05/05/2023
# 151287   A880188         Dog    05/05/2023
# 151291   A880186         Dog    05/05/2023
# 151294   A880189         Dog    05/05/2023
# 159656   A896106         Dog    11/14/2023
#
#                                            Breed              Color  \
# 82574             None    Spayed Female               730
# 85121          Partner      Intact Male                 2
# 86344           Foster          Unknown                60
# 87767           Foster          Unknown                60
# 88622        In Kennel      Intact Male                 2
# 116099          Foster          Unknown                60
# 130103         Partner    Spayed Female               730
# 137866            None    Spayed Female              4015
# 138615            None    Spayed Female               730
# 141821         Partner      Intact Male                 2
# 144911            None    Neutered Male                60
# 145394            None    Neutered Male                60
# 145773            None    Spayed Female               330
# 145786            None    Neutered Male                60
# 146149            None    Neutered Male                60
# 151285         Partner      Intact Male                 7
# 151287         Partner      Intact Male                 7
# 151291         Partner      Intact Male                 7
# 151294         Partner      Intact Male                 7
# 159656            None      Intact Male                30

# %%
#Sanity checked - male/spayed female pregnant

merged_data = merged_data.loc[(merged_data['Intake Condition'] != 'Pregnant') |
                (merged_data['Sex upon Intake'] == 'Intact Female')]

# %%
# Lastly, I want to look more closely at the "nursing" intake condition. These animals might refer to the nursing bitches (and thus should also be female) or to the nursing puppies. 

merged_data.loc[(merged_data['Intake Condition'] == 'Nursing') &
                (merged_data['Age upon Intake'] > 60)].sort_values(by = 'Age upon Intake')

# It looks like the shelter mostly uses "Nursing" to indicate nursing puppies/kittens. 
# HOWEVER, about 10% of the Nursing animals are over 8wks old (when puppies, kittens, and rabbits should be done nursing)
# And some are old enough that these are bitches/queens. There are also a few older males included; I will drop these. 
# I would like to split the young-nursing animals into another group (as being a cute puppy likely increases your odds of adoption)
# and keep the older-nursing females in a separate category (as being an older animal who has nursed recently might also change your odds of adoption).
# Out:
#        Animal ID Animal Type Date of Birth                           Breed  \
# 34991    A796707         Cat    02/04/2019              Domestic Shorthair
# 113683   A673723       Other    11/01/2013                   Rabbit Sh Mix
# 37301    A673720       Other    11/01/2013                   Rabbit Sh Mix
# 92409    A704491         Dog    02/10/2015  Labrador Retriever/Plott Hound
# 32164    A673721       Other    11/01/2013                   Rabbit Sh Mix
# ...          ...         ...           ...                             ...
# 110627   A803389         Dog    09/05/2012                 Doberman Pinsch
# 84862    A737659         Dog    11/02/2008         Chihuahua Shorthair Mix
# 81335    A775493         Dog    07/03/2012         Chihuahua Shorthair Mix
# 59422    A701255         Dog    04/26/2006                    Shih Tzu Mix
# 118280   A739289         Cat    11/30/2007          Domestic Shorthair Mix
#
#               Color    Intake Type Intake Condition Sex upon Intake  \
# 34991   Brown Tabby          Stray          Nursing         Unknown
# 113683   Blue/White  Public Assist          Nursing   Intact Female
# 37301   Black/White  Public Assist          Nursing   Intact Female
# 92409         Black          Stray          Nursing   Intact Female
# 32164   Black/White  Public Assist          Nursing   Intact Female
# ...             ...            ...              ...             ...
# 110627        Brown          Stray          Nursing   Intact Female
# 84862         Black          Stray          Nursing   Neutered Male
# 81335     Tan/White          Stray          Nursing   Spayed Female
# 59422         White          Stray          Nursing   Neutered Male
# 118280         Blue          Stray          Nursing   Spayed Female
#
#         Age upon Intake     Intake DateTime    Outcome DateTime  \
# 34991                90 2019-06-04 03:32:00 2019-06-04 06:35:00
# 113683               90 2014-03-01 10:12:00 2014-03-05 04:21:00
# 37301                90 2014-03-01 10:12:00 2014-03-05 04:19:00
# 92409                90 2015-06-05 02:05:00 2015-06-05 04:03:00
# 32164                90 2014-03-01 10:12:00 2014-03-05 04:20:00
# ...                 ...                 ...                 ...
# 110627             2190 2019-08-31 01:41:00 2019-09-06 04:49:00
# 84862              2920 2016-11-02 11:38:00 2017-01-08 02:59:00
# 81335              2920 2021-05-11 08:12:00 2018-07-03 04:14:00
# 59422              3285 2015-04-26 01:47:00 2015-05-07 12:00:00
# 118280             3285 2016-11-30 12:38:00 2017-01-15 02:25:00
#
#            Outcome Type Outcome Subtype Sex upon Outcome  Age upon Outcome
# 34991          Transfer         Partner          Unknown                90
# 113683         Transfer         Partner    Intact Female               120
# 37301          Transfer         Partner    Intact Female               120
# 92409          Transfer         Partner    Intact Female                90
# 32164          Transfer         Partner    Intact Female               120
# ...                 ...             ...              ...               ...
# 110627         Adoption            None    Spayed Female              2555
# 84862          Adoption            None    Neutered Male              2920
# 81335   Return to Owner            None    Spayed Female              2190
# 59422          Transfer         Partner    Neutered Male              3285
# 118280         Adoption            None    Spayed Female              3285
#
# [326 rows x 15 columns]

# %%
# Animals younger than 60 days (aka 8.5 weeks) will now have the Intake Condition "Nursing Juvenile"

young_nursing = merged_data.loc[(merged_data['Intake Condition'] == 'Nursing') &
                                (merged_data['Age upon Intake'] <= 60)].index
merged_data['Intake Condition'][young_nursing] = 'Nursing Juvenile'
merged_data.loc[(merged_data['Intake Condition'] == 'Nursing Juvenile') &
                                (merged_data['Age upon Intake'] <= 60)]
# Out:
# C:\Users\wisery\AppData\Local\Temp\ipykernel_132400\1473088314.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_data['Intake Condition'][young_nursing] = 'Nursing Juvenile'
#        Animal ID Animal Type Date of Birth                   Breed  \
# 50       A701811         Cat    04/20/2015  Domestic Shorthair Mix
# 137      A724640         Cat    04/05/2016  Domestic Shorthair Mix
# 149      A800717         Cat    07/18/2019      Domestic Shorthair
# 183      A728810         Cat    05/24/2016  Domestic Shorthair Mix
# 194      A793946         Cat    04/17/2019  Domestic Shorthair Mix
# ...          ...         ...           ...                     ...
# 162991   A804224         Cat    08/21/2019  Domestic Shorthair Mix
# 162992   A812494         Dog    01/15/2020  Labrador Retriever Mix
# 163130   A782910         Cat    09/24/2018  Domestic Shorthair Mix
# 163141   A808754         Cat    10/22/2019      Domestic Shorthair
# 163156   A796131         Cat    05/26/2019      Domestic Shorthair
#
#                     Color      Intake Type  Intake Condition Sex upon Intake  \
# 50             Gray Tabby            Stray  Nursing Juvenile         Unknown
# 137     Brown Tabby/Black            Stray  Nursing Juvenile     Intact Male
# 149            Blue/White            Stray  Nursing Juvenile   Intact Female
# 183                  Blue            Stray  Nursing Juvenile     Intact Male
# 194            Blue Tabby            Stray  Nursing Juvenile   Intact Female
# ...                   ...              ...               ...             ...
# 162991              Black            Stray  Nursing Juvenile     Intact Male
# 162992        Black/White  Owner Surrender  Nursing Juvenile   Intact Female
# 163130   Blue Tabby/White            Stray  Nursing Juvenile     Intact Male
# 163141              Black            Stray  Nursing Juvenile     Intact Male
# 163156  Brown Tabby/White            Stray  Nursing Juvenile     Intact Male
#
#         Age upon Intake     Intake DateTime    Outcome DateTime Outcome Type  \
# 50                   14 2015-05-05 07:29:00 2015-05-05 11:45:00     Transfer
# 137                  14 2016-04-20 08:19:00 2016-04-20 05:48:00     Transfer
# 149                   7 2019-07-25 01:49:00 2019-07-25 06:39:00     Transfer
# 183                  14 2016-06-08 05:30:00 2016-06-10 03:11:00     Transfer
# 194                  14 2019-05-02 08:21:00 2019-05-02 02:57:00     Transfer
# ...                 ...                 ...                 ...          ...
# 162991               21 2019-09-11 09:41:00 2019-09-12 11:08:00     Transfer
# 162992                7 2020-01-23 02:56:00 2020-04-07 08:50:00     Adoption
# 163130               28 2018-10-22 06:31:00 2018-12-18 07:54:00     Adoption
# 163141               21 2019-11-13 01:18:00 2019-11-13 01:50:00     Transfer
# 163156                3 2019-05-29 01:10:00 2019-05-29 04:28:00     Transfer
#
#        Outcome Subtype Sex upon Outcome  Age upon Outcome
# 50             Partner          Unknown                14
# 137            Partner      Intact Male                14
# 149            Partner    Intact Female                 7
# 183            Partner      Intact Male                14
# 194            Partner    Intact Female                14
# ...                ...              ...               ...
# 162991         Partner      Intact Male                21
# 162992          Foster    Spayed Female                60
# 163130          Foster    Neutered Male                60
# 163141         Partner      Intact Male                21
# 163156         Partner      Intact Male                 3
#
# [3495 rows x 15 columns]

# %%
# Female animals older than 4 months (the youngest age at which a female could be nursing for dogs/cats/rabbits/guinea pigs, which are the only species represented as nursing in this data)

nursing_adults = merged_data.loc[(merged_data['Intake Condition'] == 'Nursing') &
                                 (merged_data['Age upon Intake'] > 120) &
                                 ((merged_data['Sex upon Intake'] == 'Intact Female') |
                                 (merged_data['Sex upon Intake'] == 'Spayed Female'))].index
merged_data['Intake Condition'][nursing_adults] = 'Nursing Adult'
merged_data['Intake Condition'].unique()
# Out:
# C:\Users\wisery\AppData\Local\Temp\ipykernel_132400\308785821.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_data['Intake Condition'][nursing_adults] = 'Nursing Adult'
# array(['Normal', 'Injured', 'Pregnant', 'Sick', 'Nursing Juvenile',
#        'Aged', 'Nursing Adult', 'Unknown', 'Nursing', 'Congenital',
#        'Medical', 'Other', 'Neonatal', 'Med Attn', 'Feral', 'Behavior',
#        'Med Urgent', 'Space', 'Agonal', 'Neurologic', 'Panleuk', 'Parvo'],
#       dtype=object)

# %%
# Any animals lefts in the 'Nursing' Intake condition are now either male adults or age-ambiguous enough that I can't tell whether they are the mothers or the juveniles. These will be dropped.

merged_data = merged_data.loc[(merged_data['Intake Condition'] != 'Nursing')]
merged_data['Intake Condition'].unique()
# Out:
# array(['Normal', 'Injured', 'Pregnant', 'Sick', 'Nursing Juvenile',
#        'Aged', 'Nursing Adult', 'Unknown', 'Congenital', 'Medical',
#        'Other', 'Neonatal', 'Med Attn', 'Feral', 'Behavior', 'Med Urgent',
#        'Space', 'Agonal', 'Neurologic', 'Panleuk', 'Parvo'], dtype=object)

# %% [markdown]
# ### Cleaning the data - intake condition organization

# %%
merged_data['Intake Type'].unique()
#My primary question (which animals will get adopted) cannot be answered by "wildlife" or "euthanasia request" types as these animals are not eligible for adoption.
# Out:
# array(['Stray', 'Public Assist', 'Owner Surrender', 'Wildlife',
#        'Abandoned', 'Euthanasia Request'], dtype=object)

# %%
merged_data.loc[(merged_data['Animal Type'] == 'Other')]['Breed'].unique()
# Out:
# array(['Rabbit Sh Mix', 'Guinea Pig', 'Cinnamon', 'Rabbit Sh',
#        'Dutch/Angora-Satin', 'Guinea Pig Mix', 'Ferret', 'Himalayan',
#        'Cold Water', 'Bat', 'Rat Mix', 'Jersey Wooly', 'Californian',
#        'Bat Mix', 'Silver Mix', 'Rex', 'Snake/Python', 'Lop-Mini/Hotot',
#        'Lizard', 'Rat', 'Snake', 'Rex Mix', 'Rabbit Sh/Dwarf Hotot',
#        'Cold Water Mix', 'Sugar Glider', 'Hamster Mix', 'Raccoon Mix',
#        'Ferret Mix', 'Opossum Mix', 'Hedgehog', 'Lionhead',
#        'Rex-Mini Mix', 'Raccoon', 'Mouse', 'Hamster', 'Hotot',
#        'American Mix', 'Turtle', 'Angora-French Mix', 'Skunk',
#        'Californian Mix', 'Rabbit Lh', 'Lop-Amer Fuzzy', 'Coyote',
#        'Havana Mix', 'Lop-Mini Mix', 'Tortoise', 'Netherlnd Dwarf Mix',
#        'Squirrel', 'Dutch', 'Turtle Mix', 'Lop-English Mix', 'Lizard Mix',
#        'Hotot Mix', 'New Zealand Wht Mix', 'Lionhead Mix', 'Lop-Holland',
#        'Dutch Mix', 'Rabbit Lh Mix', 'Gerbil', 'Squirrel Mix',
#        'Chinchilla Mix', 'English Spot', 'Havana', 'Mouse Mix', 'Opossum',
#        'Checkered Giant Mix', 'American Sable', 'Lop-Mini', 'Tarantula',
#        'Ringtail Mix', 'Fox Mix', 'Polish Mix', 'Skunk Mix',
#        'Lizard/Bearded Dragon', 'Lop-Holland Mix', 'Coyote Mix',
#        'Dwarf Hotot', 'Tortoise Mix', 'New Zealand Wht',
#        'English Spot Mix', 'Rex-Mini', 'Beveren Mix', 'Himalayan Mix',
#        'Snake Mix', 'Gerbil Mix', 'Cottontail Mix', 'Angora-Satin Mix',
#        'Chinchilla-Stnd Mix', 'Chinchilla', 'Netherlnd Dwarf',
#        'Belgian Hare', 'Rhinelander Mix', 'Jersey Wooly Mix',
#        'Lop-Mini/Lop-Holland', 'Polish', 'Angora-English Mix',
#        'Angora-English', 'American', 'Flemish Giant Mix', 'Harlequin Mix',
#        'Britannia Petit Mix', 'Cinnamon Mix', 'Prairie Dog Mix',
#        'Lop-English', 'Flemish Giant', 'Rex/Lop-English',
#        'Hermit Crab Mix', 'Rex-Mini/Lop-English', 'Belgian Hare Mix',
#        'Chinchilla-Amer', 'Chinchilla-Stnd', 'Chinchilla-Amer Mix',
#        'Dutch/Rabbit Sh', 'Lop-Amer Fuzzy Mix', 'American Sable Mix',
#        'Angora-Satin', 'New Zealand Wht/Lop-Holland',
#        'Rabbit Sh/Lop-Mini', 'Frog', 'Tropical Mix', 'Fox', 'Snake/Snake',
#        'Florida White', 'Turtle/Redeared Slider', 'Lop-French'],
#       dtype=object)

# %%
#dropping animals with Intake Types "wildlife" & "euthanasia request"
merged_data = merged_data[(merged_data['Intake Type'] != 'Wildlife') & 
                        (merged_data['Intake Type'] != 'Euthanasia Request')]
merged_data['Intake Type'].unique()
# Out:
# array(['Stray', 'Public Assist', 'Owner Surrender', 'Abandoned'],
#       dtype=object)

# %%
outcome_data_after_drops.loc[outcome_data_after_drops['Outcome Subtype'] == 'Foster']
# Out:
#        Animal ID                DateTime Date of Birth Outcome Type  \
# 6        A814515  05/06/2020 07:59:00 AM    03/01/2018     Adoption
# 21       A822928  01/24/2022 11:49:00 AM    09/15/2010     Adoption
# 27       A765349  06/08/2018 01:04:00 PM    01/18/2009     Adoption
# 35       A812473  03/05/2020 04:15:00 PM    01/26/2010     Adoption
# 38       A789298  04/23/2019 11:59:00 AM    02/15/2019     Adoption
# ...          ...                     ...           ...          ...
# 164076   A901535  06/01/2024 01:14:00 PM    04/03/2023     Adoption
# 164077   A903054  06/01/2024 02:38:00 PM    06/01/2023     Adoption
# 164082   A761967  06/01/2024 03:12:00 PM    11/12/2013     Adoption
# 164095   A887625  06/02/2024 12:42:00 PM    08/24/2018     Adoption
# 164185   A904483  06/04/2024 12:01:00 PM    04/03/2024     Adoption
#
#        Outcome Subtype Animal Type Sex upon Outcome Age upon Outcome  \
# 6               Foster         Dog    Neutered Male          2 years
# 21              Foster         Cat    Spayed Female         11 years
# 27              Foster         Dog    Neutered Male          9 years
# 35              Foster         Dog    Neutered Male         10 years
# 38              Foster         Dog    Neutered Male         2 months
# ...                ...         ...              ...              ...
# 164076          Foster         Cat    Spayed Female           1 year
# 164077          Foster         Dog    Spayed Female           1 year
# 164082          Foster         Dog    Neutered Male         10 years
# 164095          Foster         Dog    Neutered Male          5 years
# 164185          Foster         Cat    Intact Female         2 months
#
#                                        Breed        Color
# 6       American Foxhound/Labrador Retriever  White/Brown
# 21                        Domestic Shorthair       Torbie
# 27                   Chihuahua Shorthair Mix     Tricolor
# 35                       Chihuahua Shorthair        Brown
# 38                    Labrador Retriever Mix  Brown/White
# ...                                      ...          ...
# 164076                            Bengal Mix  Brown Tabby
# 164077                       German Shepherd        Sable
# 164082                Labrador Retriever Mix  Black/White
# 164095                              Pit Bull   Blue/White
# 164185                    Domestic Shorthair        Black
#
# [16394 rows x 10 columns]

# %%
outcome_data_after_drops.loc[(outcome_data_after_drops['Outcome Type'].isnull()) & (outcome_data_after_drops['Outcome Subtype'].isnull()==False)]
# Out:
#        Animal ID MonthYear Date of Birth Outcome Type Outcome Subtype  \
# 38121    A828974  Feb 2021    01/30/2019          NaN             Snr
# 156108   A890645  Dec 2023    09/11/2023          NaN          Foster
#
#        Animal Type Sex upon Outcome Age upon Outcome               Breed  \
# 38121          Cat    Spayed Female          2 years  Domestic Shorthair
# 156108         Cat    Spayed Female         3 months         Siamese Mix
#
#              Color
# 38121        Black
# 156108  Lynx Point

# %%
lost_to_follow_up = outcome_data_after_drops.loc[outcome_data_after_drops['Outcome Type'].isnull()]
# Out:
# (0, 10)
