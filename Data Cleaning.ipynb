# %%
# In this notebook, I have a data set from the Austin Animal Center that I would like to use to answer some questions about the shelter. 
# Before I can start really analyzing the data, first the data sets need to be cleaned, and I would like to consolidate the two files 
# (intake and outcome) into one file that I can use for all my analysis. Because I don't yet have a specific question in mind, I will 
# focus mostly on getting rid of null values and sensitive information, and doing some logic checking to make sure the data is as trustworthy as possible.

# %%
import pandas as pd

# %% [markdown]
# ### Import and initial description of intake data

# %%
#read both the intake and outcome data files
intake_data_raw = pd.read_csv('Austin_Animal_Center_Intakes_20240701.csv')
outcome_data_raw = pd.read_csv('Austin_Animal_Center_Outcomes_20240701.csv')

# %%
intake_data_raw.head()
intake_length = len(intake_data_raw)
#intake_length #164614
#Name and Found Location are potentially sensitive information, so I will drop these. 
#Animal ID can be used to join the intake and outcome data sets, so I will keep it for now.
#MonthYear and DateTime are redundant, so I will drop MonthYear since DateTime should be easy to convert from str to timestamp or other numerical.

# %%
outcome_length = len(outcome_data_raw)
outcome_data_raw.head()
#outcome_length #164228
#Name is again potentially sensitive. The Animal ID will be used for merging.
#MonthYear and DateTime are again redundant.
#The outcome data is shorter than the intake data, likely because some pets are actively in the shelter (so they have intake but no outcome yet)
# Out:
#   Animal ID   Name                DateTime MonthYear Date of Birth  \
# 0   A794011  Chunk  05/08/2019 06:20:00 PM  May 2019    05/02/2017
# 1   A776359  Gizmo  07/18/2018 04:02:00 PM  Jul 2018    07/12/2017
# 2   A821648    NaN  08/16/2020 11:38:00 AM  Aug 2020    08/16/2019
# 3   A720371  Moose  02/13/2016 05:59:00 PM  Feb 2016    10/08/2015
# 4   A674754    NaN  03/18/2014 11:47:00 AM  Mar 2014    03/12/2014
#
#   Outcome Type Outcome Subtype Animal Type Sex upon Outcome Age upon Outcome  \
# 0    Rto-Adopt             NaN         Cat    Neutered Male          2 years
# 1     Adoption             NaN         Dog    Neutered Male           1 year
# 2   Euthanasia             NaN       Other          Unknown           1 year
# 3     Adoption             NaN         Dog    Neutered Male         4 months
# 4     Transfer         Partner         Cat      Intact Male           6 days
#
#                                 Breed              Color
# 0              Domestic Shorthair Mix  Brown Tabby/White
# 1             Chihuahua Shorthair Mix        White/Brown
# 2                             Raccoon               Gray
# 3  Anatol Shepherd/Labrador Retriever               Buff
# 4              Domestic Shorthair Mix       Orange Tabby

# %% [markdown]
# ### Duplicate Detection & Removal

# %%
intake_data_raw['Animal ID'].value_counts()
#Animal ID is not unique because a single animal may go through the shelter system multiple times
# Out:
# Animal ID
# A721033    33
# A718223    14
# A718877    12
# A705625    11
# A706536    11
#            ..
# A714773     1
# A765646     1
# A732323     1
# A698657     1
# A855904     1
# Name: count, Length: 147862, dtype: int64

# %%
#Looking more closely at the most frequently intaken pet, we see these are not duplicate data, but actually 33 unique visits to the shelter. 
#The other pets with multiple entries of the same Animal ID tell similar stories. 
intake_data_raw.loc[(intake_data_raw['Animal ID'] == 'A721033')].sort_values(by = 'DateTime')
# Out:
#        Animal ID     Name                DateTime       MonthYear  \
# 118002   A721033  Lil Bit  01/09/2017 02:26:00 PM    January 2017
# 125351   A721033  Lil Bit  01/26/2017 06:55:00 AM    January 2017
# 48856    A721033  Lil Bit  01/30/2017 11:05:00 PM    January 2017
# 110181   A721033  Lil Bit  02/06/2017 10:13:00 AM   February 2017
# 30692    A721033  Lil Bit  02/12/2019 10:21:00 AM   February 2019
# 69901    A721033  Lil Bit  02/16/2019 10:30:00 AM   February 2019
# 38877                6317 E Ben White Blvd in Austin (TX)          Stray
# 42912                    Burton And Oltorf in Austin (TX)  Public Assist
# 137932                  606 West Slaughter in Austin (TX)  Public Assist
# 146777               1500 Red River Street in Austin (TX)  Public Assist
# 121342                    6010 E Riverside in Austin (TX)  Public Assist
# 45736   East 7Th Street And Pleasant Valley in Austin ...  Public Assist
# 115943         Justin Lane And North Lamar in Austin (TX)  Public Assist
# 32505                     863 Airport Blvd in Austin (TX)  Public Assist
# 24133                    Shady And Airport in Austin (TX)  Public Assist
# 32881               1135 Airport Boulevard in Austin (TX)  Public Assist
# 31062               6200 E. Ben White Blvd in Austin (TX)  Public Assist
# 99184                         9300 S Ih 35 in Austin (TX)  Public Assist
# 44244   S Pleasant Valley Rd And E Riverside Dr in Aus...  Public Assist
# 76047                         1144 Airport in Austin (TX)  Public Assist
#
#        Intake Condition Animal Type Sex upon Intake Age upon Intake  \
# 118002          Injured         Dog   Neutered Male          1 year
# 125351           Normal         Dog   Neutered Male          1 year
# 48856            Normal         Dog   Neutered Male          1 year
# 110181           Normal         Dog   Neutered Male          1 year
# 30692            Normal         Dog   Neutered Male         3 years
# 69901            Normal         Dog   Neutered Male         3 years
# 102945           Normal         Dog   Neutered Male        9 months
# 150333           Normal         Dog   Neutered Male         2 years
# 5518             Normal         Dog   Neutered Male         3 years
# 13100            Normal         Dog   Neutered Male         2 years
# 48146            Normal         Dog   Neutered Male         3 years
# 60977            Normal         Dog   Neutered Male         2 years
# 28649            Normal         Dog   Neutered Male          1 year
# 16155            Normal         Dog   Neutered Male         2 years
# 62129            Normal         Dog   Neutered Male         2 years
# 85455            Normal         Dog   Neutered Male         2 years
# 61423            Normal         Dog   Neutered Male         3 years
# 15563            Normal         Dog   Neutered Male         4 years
# 118283           Normal         Dog   Neutered Male         3 years
# 38877            Normal         Dog   Neutered Male          1 year
# 42912            Normal         Dog   Neutered Male         4 years
# 137932           Normal         Dog   Neutered Male         3 years
# 146777           Normal         Dog   Neutered Male         3 years
# 121342           Normal         Dog   Neutered Male          1 year
# 45736            Normal         Dog   Neutered Male         3 years
# 115943           Normal         Dog   Neutered Male         4 years
# 32505            Normal         Dog   Neutered Male         3 years
# 24133            Normal         Dog   Neutered Male         3 years
# 32881            Normal         Dog   Neutered Male         4 years
# 31062            Normal         Dog   Neutered Male          1 year
# 99184            Normal         Dog   Neutered Male         3 years
# 44244            Normal         Dog   Neutered Male          1 year
# 76047            Normal         Dog   Neutered Male         3 years
#
#                   Breed                   Color
# 118002  Rat Terrier Mix  Tricolor/Brown Brindle
# 125351  Rat Terrier Mix  Tricolor/Brown Brindle
# 48856   Rat Terrier Mix  Tricolor/Brown Brindle
# 110181  Rat Terrier Mix  Tricolor/Brown Brindle
# 30692   Rat Terrier Mix  Tricolor/Brown Brindle
# 69901   Rat Terrier Mix  Tricolor/Brown Brindle
# 102945  Rat Terrier Mix  Tricolor/Brown Brindle
# 150333  Rat Terrier Mix  Tricolor/Brown Brindle
# 5518    Rat Terrier Mix  Tricolor/Brown Brindle
# 13100   Rat Terrier Mix  Tricolor/Brown Brindle
# 48146   Rat Terrier Mix  Tricolor/Brown Brindle
1 year  Rat Terrier Mix  Tricolor/Brown Brindle
# 42029            1 year  Rat Terrier Mix  Tricolor/Brown Brindle
# 83153            1 year  Rat Terrier Mix  Tricolor/Brown Brindle
# 67815            1 year  Rat Terrier Mix  Tricolor/Brown Brindle
# 136111          3 years  Rat Terrier Mix  Tricolor/Brown Brindle
# 37003           3 years  Rat Terrier Mix  Tricolor/Brown Brindle
# 74377          9 months  Rat Terrier Mix  Tricolor/Brown Brindle
# 90560           2 years  Rat Terrier Mix  Tricolor/Brown Brindle
# 51640           3 years  Rat Terrier Mix  Tricolor/Brown Brindle
# 108849          2 years  Rat Terrier Mix  Tricolor/Brown Brindle
# 16690           3 years  Rat Terrier Mix  Tricolor/Brown Brindle
# 95326            1 year  Rat Terrier Mix  Tricolor/Brown Brindle
# 27354           2 years  Rat Terrier Mix  Tricolor/Brown Brindle
# 59307           2 years  Rat Terrier Mix  Tricolor/Brown Brindle
# 130187          2 years  Rat Terrier Mix  Tricolor/Brown Brindle
# 51367           2 years  Rat Terrier Mix  Tricolor/Brown Brindle
# 31171           3 years  Rat Terrier Mix  Tricolor/Brown Brindle
# 19668           4 years  Rat Terrier Mix  Tricolor/Brown Brindle
# 139867          3 years  Rat Terrier Mix  Tricolor/Brown Brindle
# 69402            1 year  Rat Terrier Mix  Tricolor/Brown Brindle
# 69340           3 years  Rat Terrier Mix  Tricolor/Brown Brindle
# 4949            4 years  Rat Terrier Mix  Tricolor/Brown Brindle
# 42872           3 years  Rat Terrier Mix  Tricolor/Brown Brindle
# 88456           3 years  Rat Terrier Mix  Tricolor/Brown Brindle
# 99620            1 year  Rat Terrier Mix  Tricolor/Brown Brindle
# 68092           4 years  Rat Terrier Mix  Tricolor/Brown Brindle
# 83424           3 years  Rat Terrier Mix  Tricolor/Brown Brindle
# 54887           3 years  Rat Terrier Mix  Tricolor/Brown Brindle
# 73224           4 years  Rat Terrier Mix  Tricolor/Brown Brindle
# 13829            1 year  Rat Terrier Mix  Tricolor/Brown Brindle
# 24355           3 years  Rat Terrier Mix  Tricolor/Brown Brindle
# 98239            1 year  Rat Terrier Mix  Tricolor/Brown Brindle
# 94443           3 years  Rat Terrier Mix  Tricolor/Brown Brindle

# %%
#To merge the intake and outcome datasets while keeping the multiple-visit pets in the set, I will group by Animal ID to assign each visit a count, combine the Animal ID with the count, and merge along this key
#First I want to sort the datasets by DateTime, which means my current DateTime str needs to be convert to a numerical. 
intake_data_raw['DateTime'] = pd.to_datetime(intake_data_raw['DateTime'], format = '%m/%d/%Y %I:%M:%S %p')
outcome_data_raw['DateTime'] = pd.to_datetime(outcome_data_raw['DateTime'], format = '%m/%d/%Y %I:%M:%S %p')

# %%
#Sorting the datasets by DateTime and dropping rows that have the same Animal ID & DateTime (ie. true duplicate entries)
intake_data_raw = intake_data_raw.sort_values(by = 'DateTime')
intake_data_raw['Duplicated?'] = intake_data_raw.duplicated(subset=['Animal ID', 'DateTime'])

outcome_data_raw = outcome_data_raw.sort_values(by = 'DateTime')
outcome_data_raw['Duplicated?'] = outcome_data_raw.duplicated(subset=['Animal ID', 'DateTime'])

# %%
#Spotchecking that duplicates that were flagged are true duplicates and not repeat visits and checking the length of each to see how many were dropped. 
#It worked =)

#outcome_data_raw.loc[outcome_data_raw['Duplicated?'] == True] #25 count
#intake_data_raw.loc[intake_data_raw['Duplicated?'] == True] #37 count
#intake_data_raw.loc[intake_data_raw['Animal ID'] == 'A727043']

# %%
outcome_data_raw = outcome_data_raw.loc[outcome_data_raw['Duplicated?'] != True]
#len(outcome_data_raw) #164203 length

intake_data_raw = intake_data_raw.loc[intake_data_raw['Duplicated?'] != True]
#len(intake_data_raw) #164577 length

# %% [markdown]
# ### Merging intake & outcome data sets

# %%
intake_data_raw.loc[(intake_data_raw['Animal ID'] == 'A659667')]
# Out:
#        Animal ID Name            DateTime     MonthYear  \
# 142924   A659667  NaN 2013-10-26 15:03:00  October 2013
#
#                         Found Location Intake Type Intake Condition  \
# 142924  12507 Esplanade in Austin (TX)       Stray           Normal
#
#        Animal Type Sex upon Intake Age upon Intake                  Breed  \
# 142924         Cat   Neutered Male         8 years  Domestic Longhair Mix
#
#              Color  Duplicated?
# 142924  Blue/White        False

# %%
outcome_data_raw.loc[(outcome_data_raw['Animal ID'] == 'A659667')]
# Out:
#        Animal ID Name            DateTime MonthYear Date of Birth  \
# 109613   A659667  NaN 2013-10-26 13:34:00  Oct 2013    07/28/2005
#
#        Outcome Type Outcome Subtype Animal Type Sex upon Outcome  \
# 109613     Transfer            SCRP         Cat    Neutered Male
#
#        Age upon Outcome                  Breed       Color  Duplicated?
# 109613          8 years  Domestic Longhair Mix  Blue/White        False

# %%
merged_data_unfiltered = pd.merge(intake_data_raw, outcome_data_raw, on='Animal ID', suffixes=('_intake', '_outcome'))

# There are a number of pets who were in the shelter at the time that data collection started, so they have outcome data 
# before they have intake data. This will discard the first outcome data, so their visits are matched correctly.
merged_data_raw = merged_data_unfiltered[merged_data_unfiltered['DateTime_outcome'] >= merged_data_unfiltered['DateTime_intake']]

# %%
#When I examine the animals that did not make it into the merged set from the outcome data, most of them are from the time the shelter first started recording data (Oct 1, 2013). 
#Pets admitted prior to this date, would not have intake data to match with their outcome data, so they cannot be included. 
#There are a few pets from later on that are also missing intake data for some reason. None of these pets have multiple visits, so they will not mess up the merged data set. 

outcome_data_not_merged = outcome_data_raw[~outcome_data_raw['Animal ID'].isin(merged_data_raw['Animal ID'])]
outcome_data_not_merged.loc[outcome_data_not_merged['DateTime'] < '2023'].sort_values(by = 'DateTime')
# Out:
#        Animal ID       Name            DateTime MonthYear Date of Birth  \
# 65866    A659834    *Dudley 2013-10-01 09:31:00  Oct 2013    07/23/2013
# 13012    A664223       Moby 2013-10-01 11:03:00  Oct 2013    09/30/2009
# 34753    A663646        NaN 2013-10-01 11:12:00  Oct 2013    09/22/2010
# 126159   A663888        NaN 2013-10-01 11:13:00  Oct 2013    09/25/2011
# 32550    A663833  Baby Girl 2013-10-01 11:50:00  Oct 2013    09/24/2004
# ...          ...        ...                 ...       ...           ...
# 112967   A868562        NaN 2022-11-05 15:08:00  Nov 2022    11/05/2020
# 32011    A868557        NaN 2022-11-05 15:10:00  Nov 2022    11/05/2020
# 150127   A869983        NaN 2022-11-29 14:47:00  Nov 2022    05/29/2022
# 78723    A870677        NaN 2022-12-10 15:12:00  Dec 2022    12/10/2020
# 119500   A870894         #2 2022-12-14 11:20:00  Dec 2022    12/14/2022
#
#            Outcome Type Outcome Subtype Animal Type Sex upon Outcome  \
# 65866          Adoption          Foster         Dog    Neutered Male
# 13012   Return to Owner             NaN         Dog    Neutered Male
# 34753          Transfer         Partner         Dog    Neutered Male
# 126159         Transfer         Partner         Dog    Spayed Female
# 32550   Return to Owner             NaN         Dog    Spayed Female
# ...                 ...             ...         ...              ...
# 112967       Euthanasia     Rabies Risk       Other          Unknown
# 32011        Euthanasia     Rabies Risk       Other          Unknown
# 150127       Euthanasia       Suffering         Cat          Unknown
# 78723              Died       In Kennel       Other          Unknown
# 119500             Died       In Kennel         Cat          Unknown
#
#        Age upon Outcome                   Breed        Color  Duplicated?
# 65866          2 months  Labrador Retriever Mix        Black        False
# 13012           4 years             Bulldog Mix        White        False
# 34753           3 years          Toy Poodle Mix        White        False
# 126159          2 years               Boxer Mix    Red/White        False
# 32550           9 years  Labrador Retriever Mix        Black        False
# ...                 ...                     ...          ...          ...
# 112967          2 years                     Fox   Gray/Brown        False
# 32011           2 years                 Raccoon   Black/Gray        False
# 150127         6 months      Domestic Shorthair  Brown Tabby        False
# 78723           2 years                 Raccoon   Black/Gray        False
# 119500          0 years      Domestic Shorthair  Cream Tabby        False
#
# [1366 rows x 13 columns]

# %%
# When I examine the animals that did not make it into the merged set from the intake data, almost all of them (1126/1771) are from 2024, so there is a good chance these pets do not yet have outcomes.
# There are some animals that have intake data recorded AFTER their outcome data, and for some of these, I suspect clerical errors, but that data is not trustworthy for answering time-associated questions

intake_data_not_merged = intake_data_raw[~intake_data_raw['Animal ID'].isin(merged_data_raw['Animal ID'])]
intake_data_not_merged

#intake_data_not_merged.loc[intake_data_not_merged['DateTime'] >= '2024'].sort_values(by = 'DateTime')
#intake_data_not_merged.loc[intake_data_not_merged['DateTime'] < '2023'].sort_values(by = 'DateTime')
# Out:
#        Animal ID  Name            DateTime      MonthYear  \
# 142993   A665649   NaN 2013-10-21 11:12:00   October 2013
# 142924   A659667   NaN 2013-10-26 15:03:00   October 2013
# 14142    A672696  Oreo 2014-02-15 12:30:00  February 2014
# 50398    A673335   NaN 2014-02-22 13:03:00  February 2014
# 55548    A674638   Sam 2014-03-16 11:46:00     March 2014
# ...          ...   ...                 ...            ...
# 163526   A908486   NaN 2024-07-01 09:09:00      July 2024
# 163521   A908489   NaN 2024-07-01 09:09:00      July 2024
# 163528   A908485   NaN 2024-07-01 09:09:00      July 2024
# 163523   A908487   NaN 2024-07-01 09:09:00      July 2024
# 163522   A908490   NaN 2024-07-01 09:09:00      July 2024
#
#                                   Found Location Intake Type Intake Condition  \
# 142993            12507 Esplanade in Austin (TX)       Stray           Normal
# 142924            12507 Esplanade in Austin (TX)       Stray           Normal
# 14142           2 Brett Cove in Rollingwood (TX)       Stray           Normal
# 50398        4415 Secluded Hollow in Austin (TX)    Wildlife             Sick
# 55548   Rollingwood & Bee Cave Rd in Austin (TX)       Stray           Normal
# ...                                          ...         ...              ...
# 163526               4216 Gochman in Austin (TX)       Stray         Neonatal
# 163521               4216 Gochman in Austin (TX)       Stray         Neonatal
# 163528               4216 Gochman in Austin (TX)       Stray         Neonatal
# 163523               4216 Gochman in Austin (TX)       Stray         Neonatal
# 163522               4216 Gochman in Austin (TX)       Stray         Neonatal
#
#        Animal Type Sex upon Intake Age upon Intake                   Breed  \
# 142993         Cat         Unknown          1 year  Domestic Shorthair Mix
# 142924         Cat   Neutered Male         8 years   Domestic Longhair Mix
# 14142          Dog   Neutered Male        12 years         Rat Terrier Mix
# 50398        Other         Unknown         2 years                 Raccoon
# 55548          Dog   Neutered Male         7 years  Labrador Retriever Mix
# ...            ...             ...             ...                     ...
# 163526         Cat         Unknown         4 weeks      American Shorthair
# 163521         Cat         Unknown         4 weeks      American Shorthair
# 163528         Cat         Unknown         4 weeks      American Shorthair
# 163523         Cat         Unknown         4 weeks      American Shorthair
# 163522         Cat         Unknown         4 weeks      American Shorthair
#
#               Color  Duplicated?
# 142993        Black        False
# 142924   Blue/White        False
# 14142      Tricolor        False
# 50398    Black/Gray        False
# 55548     Chocolate        False
# ...             ...          ...
# 163526  Black/Black        False
# 163521  Black/Black        False
# 163528  Black/Black        False
# 163523  Black/Black        False
# 163522  Black/Black        False
#
# [1771 rows x 13 columns]

# %% [markdown]
# ### Cleaning the merged data set - Nulls

# %%
merged_data_raw.columns
# Looking at the columns of the merged data set, there are several columns that should be identical (ex. Breed_x & Breed_y),
# some columns are redundant (monthyear), and some are not helpful (Duplicated?)
# Out:
# Index(['Animal ID', 'Name_intake', 'DateTime_intake', 'MonthYear_intake',
#        'Found Location', 'Intake Type', 'Intake Condition',
#        'Animal Type_intake', 'Sex upon Intake', 'Age upon Intake',
#        'Breed_intake', 'Color_intake', 'Duplicated?_intake', 'Name_outcome',
#        'DateTime_outcome', 'MonthYear_outcome', 'Date of Birth',
#        'Outcome Type', 'Outcome Subtype', 'Animal Type_outcome',
#        'Sex upon Outcome', 'Age upon Outcome', 'Breed_outcome',
#        'Color_outcome', 'Duplicated?_outcome'],
#       dtype='object')

# %%
#First I will make sure that the columns that should be identical actually are.

#merged_data_raw.loc[(merged_data_raw['Breed_intake'] == merged_data_raw['Breed_outcome']) == False] 
#merged_data_raw.loc[(merged_data_raw['Animal Type_intake'] == merged_data_raw['Animal Type_outcome']) == False]
#merged_data_raw.loc[(merged_data_raw['Color_intake'] == merged_data_raw['Color_outcome']) == False]

# %%
# Since all of those duplicate columns matched like they should, I can drop the duplicates without issue. 
# I will also drop the sensitive, redundant, and not helpful data. 

merged_data = merged_data_raw.drop(['Name_intake', 'MonthYear_intake', 'Found Location', 'Duplicated?_intake', 'Name_outcome', 'MonthYear_outcome', 'Animal Type_outcome', 'Breed_outcome', 'Color_outcome', 'Duplicated?_outcome'], axis = 1)
merged_data.head()
# Out:
#   Animal ID     DateTime_intake Intake Type Intake Condition  \
# 0   A521520 2013-10-01 07:51:00       Stray           Normal
# 1   A664235 2013-10-01 08:33:00       Stray           Normal
# 2   A664237 2013-10-01 08:33:00       Stray           Normal
# 3   A664236 2013-10-01 08:33:00       Stray           Normal
# 4   A664233 2013-10-01 08:53:00       Stray          Injured
#
#   Animal Type_intake Sex upon Intake Age upon Intake  \
# 0                Dog   Spayed Female         7 years
# 1                Cat         Unknown          1 week
# 2                Cat         Unknown          1 week
# 3                Cat         Unknown          1 week
# 4                Dog   Intact Female         3 years
#
#                    Breed_intake  Color_intake    DateTime_outcome  \
# 0  Border Terrier/Border Collie     White/Tan 2013-10-01 15:39:00
# 1        Domestic Shorthair Mix  Orange/White 2013-10-01 10:39:00
# 2        Domestic Shorthair Mix  Orange/White 2013-10-01 10:44:00
# 3        Domestic Shorthair Mix  Orange/White 2013-10-01 10:44:00
# 4                  Pit Bull Mix    Blue/White 2013-10-01 15:33:00
#
#   Date of Birth     Outcome Type Outcome Subtype Sex upon Outcome  \
# 0    09/07/2006  Return to Owner             NaN    Spayed Female
# 1    09/24/2013         Transfer         Partner          Unknown
# 2    09/24/2013         Transfer         Partner          Unknown
# 3    09/24/2013         Transfer         Partner          Unknown
# 4    09/30/2010       Euthanasia       Suffering    Intact Female
#
#   Age upon Outcome
# 0          7 years
# 1           1 week
# 2           1 week
# 3           1 week
# 4          3 years

# %%
# And renaming some columns to improve organization. 
merged_data = merged_data.rename({'DateTime_intake': 'Intake DateTime', 'Animal Type_intake': 'Animal Type', 'Breed_intake': 'Breed', 'Color_intake':'Color', 'DateTime_outcome': 'Outcome DateTime'}, axis='columns')
merged_data = merged_data.reindex(columns = ['Animal ID', 'Animal Type', 'Date of Birth', 'Breed', 'Color', 'Intake Type', 'Intake Condition', 'Sex upon Intake', 'Age upon Intake', 'Intake DateTime', 'Outcome DateTime', 'Outcome Type', 'Outcome Subtype', 'Sex upon Outcome', 'Age upon Outcome'])
merged_data.head()
# Out:
#   Animal ID Animal Type Date of Birth                         Breed  \
# 0   A521520         Dog    09/07/2006  Border Terrier/Border Collie
# 1   A664235         Cat    09/24/2013        Domestic Shorthair Mix
# 2   A664237         Cat    09/24/2013        Domestic Shorthair Mix
# 3   A664236         Cat    09/24/2013        Domestic Shorthair Mix
# 4   A664233         Dog    09/30/2010                  Pit Bull Mix
#
#           Color Intake Type Intake Condition Sex upon Intake Age upon Intake  \
# 0     White/Tan       Stray           Normal   Spayed Female         7 years
# 1  Orange/White       Stray           Normal         Unknown          1 week
# 2  Orange/White       Stray           Normal         Unknown          1 week
# 3  Orange/White       Stray           Normal         Unknown          1 week
# 4    Blue/White       Stray          Injured   Intact Female         3 years
#
#       Intake DateTime    Outcome DateTime     Outcome Type Outcome Subtype  \
# 0 2013-10-01 07:51:00 2013-10-01 15:39:00  Return to Owner             NaN
# 1 2013-10-01 08:33:00 2013-10-01 10:39:00         Transfer         Partner
# 2 2013-10-01 08:33:00 2013-10-01 10:44:00         Transfer         Partner
# 3 2013-10-01 08:33:00 2013-10-01 10:44:00         Transfer         Partner
# 4 2013-10-01 08:53:00 2013-10-01 15:33:00       Euthanasia       Suffering
#
#   Sex upon Outcome Age upon Outcome
# 0    Spayed Female          7 years
# 1          Unknown           1 week
# 2          Unknown           1 week
# 3          Unknown           1 week
# 4    Intact Female          3 years

# %%
merged_data.loc[(merged_data['Animal ID'] == 'A661830')]
# Out:
#     Animal ID Animal Type Date of Birth                     Breed   Color  \
# 830   A661830         Cat    08/25/2012  Domestic Medium Hair Mix  Torbie
#
#     Intake Type Intake Condition Sex upon Intake Age upon Intake  \
# 830       Stray           Normal   Intact Female          1 year
#
#         Intake DateTime    Outcome DateTime Outcome Type Outcome Subtype  \
# 830 2013-10-15 08:25:00 2013-10-17 17:58:00     Transfer            SCRP
#
#     Sex upon Outcome Age upon Outcome
# 830    Intact Female           1 year

# %%
merged_data.describe(include = 'all')
# The data set contains over 180k animals. All of this information could potentially effect outcome (adoption vs other).
# There is still some redundant information between "age upon intake," "Date of Birth," and "age upon outcome," 
# but different questions might be more easily answered with one vs another, so I will leave them
# Out:
#        Animal ID Animal Type Date of Birth                   Breed  \
# count     185717      185717        185717                  185717
# unique    146091           5          8375                    2933
# top      A721033         Dog    05/20/2015  Domestic Shorthair Mix
# freq         561      109468           603                   35153
# mean         NaN         NaN           NaN                     NaN
# min          NaN         NaN           NaN                     NaN
# 25%          NaN         NaN           NaN                     NaN
# 50%          NaN         NaN           NaN                     NaN
# 75%          NaN         NaN           NaN                     NaN
# max          NaN         NaN           NaN                     NaN
#
#               Color Intake Type Intake Condition Sex upon Intake  \
# count        185717      185717           185717          185715
# unique          647           6               20               5
# top     Black/White       Stray           Normal     Intact Male
# freq          19818      126863           160601           62181
# mean            NaN         NaN              NaN             NaN
# min             NaN         NaN              NaN             NaN
# 25%             NaN         NaN              NaN             NaN
# 50%             NaN         NaN              NaN             NaN
# 75%             NaN         NaN              NaN             NaN
# max             NaN         NaN              NaN             NaN
#
#        Age upon Intake                Intake DateTime  \
# count           185716                         185717
# unique              55                            NaN
# top             1 year                            NaN
# freq             31806                            NaN
# mean               NaN  2018-06-09 08:22:44.187554048
# min                NaN            2013-10-01 07:51:00
# 25%                NaN            2015-11-25 08:33:00
# 50%                NaN            2018-03-09 11:34:00
# 75%                NaN            2020-09-11 12:58:00
# max                NaN            2024-06-30 13:24:00
#
#                      Outcome DateTime Outcome Type Outcome Subtype  \
# count                          185717       185668           79884
# unique                            NaN           11              26
# top                               NaN     Adoption         Partner
# freq                              NaN        88977           41057
# mean    2018-08-13 15:19:55.906998272          NaN             NaN
# min               2013-10-01 10:39:00          NaN             NaN
# 25%               2016-02-16 19:08:00          NaN             NaN
# 50%               2018-06-02 18:03:00          NaN             NaN
# 75%               2020-12-09 12:45:00          NaN             NaN
# max               2024-07-01 11:15:00          NaN             NaN
#
#        Sex upon Outcome Age upon Outcome
# count            185715           185707
# unique                5               55
# top       Neutered Male           1 year
# freq              69603            31756
# mean                NaN              NaN
# min                 NaN              NaN
# 25%                 NaN              NaN
# 50%                 NaN              NaN
# 75%                 NaN              NaN
# max                 NaN              NaN

# %%
merged_data.isnull().sum()
# There are a number of null values throughout the data set, 
# The "outcome subtype" is the largest cluster because not every Outcome Type needs to be further described by a Subtype
# Options for handling the subtype nulls include: 
#      marking the nulls as "Unspecific" or similar placeholder, 
#      dropping the subtype variable altogether, 
#      combining the type-subtype data into one variable. 
# For now, I will mark the Nan Subtypes as Not Specified, but I might circle back to this later.
# Out:
# Animal ID                0
# Animal Type              0
# Date of Birth            0
# Breed                    0
# Color                    0
# Intake Type              0
# Intake Condition         0
# Sex upon Intake          2
# Age upon Intake          1
# Intake DateTime          0
# Outcome DateTime         0
# Outcome Type            49
# Outcome Subtype     105833
# Sex upon Outcome         2
# Age upon Outcome        10
# dtype: int64

# %%
merged_data['Outcome Subtype'] = merged_data['Outcome Subtype'].fillna(value = 'Not Specified')

# %%
merged_data.loc[merged_data['Outcome Type'].isnull() == True]

# There are a few pets that have no recorded Outcome type, and these can't help answer my questions about what gets pets adopted, so I will drop them. 

merged_data = merged_data.loc[merged_data['Outcome Type'].isnull() != True]

# %%
merged_data = merged_data.loc[merged_data['Sex upon Outcome'].isnull() != True]

# %%
merged_data.loc[merged_data['Age upon Outcome'].isnull() == True]

# There are a few pets that have no recorded age or sex upon outcome. 
# For a couple of these, they have an "age upon intake," so "age upon outcome" 
# can easily be calculated and filled in, but because my data set is large, I'm going to drop these. 

merged_data = merged_data.dropna(subset = ['Age upon Outcome'], axis = 0)

#merged_data = merged_data.loc[merged_data['Age upon Outcome'].isnull() != True &
#                             merged_data['Sex upon Outcome'].isnull() !=]

# %%
merged_data.isnull().sum()
# Out:
# Animal ID           0
# Animal Type         0
# Date of Birth       0
# Breed               0
# Color               0
# Intake Type         0
# Intake Condition    0
# Sex upon Intake     0
# Age upon Intake     0
# Intake DateTime     0
# Outcome DateTime    0
# Outcome Type        0
# Outcome Subtype     0
# Sex upon Outcome    0
# Age upon Outcome    0
# dtype: int64

# %%
# Since I hope this data analysis can be repeated on updated data in the future, I put the above
# null management sequence into a method that can go in a module

def drop_null_data(df):
    #identifies null data in provided data frame, drops it, and reports columns in which the data were null

    #generates a Series with index = df's columns, values = number of nulls per column
    drops = df.isnull().sum()

    #if there are no nulls in the df, print & return original df
    if drops.sum() == 0:
        print("No null values identified")
            
    #if there are nulls in the df, drop them all and print which columns contained nulls and how many were dropped; returns df without nulls    
    else:
        df = df.dropna(axis = 0)
        for index, value in drops.items():
            if value != 0:
                print('"{}" contained {} null value(s)'.format(index, value))
    return df

# %% [markdown]
# ### Cleaning the merged data set - Sanity Checks

# %% [markdown]
# ##### Ages - Neonates & Aged

# %%
# The data contains a small number of animals that have ages listed as negative numbers. 
# They are few enough that I could drop them, but I prefer to fix them. 

merged_data['Age upon Intake'].unique()
# Out:
# array(['7 years', '1 week', '3 years', '4 months', '8 years', '17 years',
#        '4 years', '1 year', '3 weeks', '6 years', '5 years', '2 years',
#        '1 weeks', '2 months', '8 months', '0 years', '1 month',
#        '3 months', '9 months', '4 weeks', '10 months', '6 months',
#        '2 weeks', '7 months', '5 months', '12 years', '16 years',
#        '15 years', '10 years', '9 years', '3 days', '11 months', '2 days',
#        '4 days', '11 years', '1 day', '14 years', '13 years', '18 years',
#        '5 weeks', '19 years', '20 years', '5 days', '6 days', '22 years',
#        '-1 years', '-3 years', '25 years', '-2 years', '24 years',
#        '-4 years', '21 years', '23 years', '30 years', '28 years'],
#       dtype=object)

# %%
# This method will use regex to convert the ages from strings to ints
# I leave the ages in days because the computer doesn't need years/months/weeks/days to draw conclusions, 
# but for data visualization later, they will need to be converted to more meaningful numbers.

import re

year_pattern = re.compile(r"(-?\d+)\s*(?:year|years)")
month_pattern = re.compile(r"(-?\d+)\s*(?:month|months)")
week_pattern = re.compile(r"(-?\d+)\s*(?:week|weeks)")
day_pattern = re.compile(r"(-?\d+)\s*(?:day|days)")

# Function to convert strings to days
def convert_to_days(age_str):
    if "year" in age_str:
        value = re.search(year_pattern, age_str).group(1)
        return int(value) * 365
    elif "month" in age_str:
        value = re.search(month_pattern, age_str).group(1)
        return int(value) * 30 
    elif "week" in age_str:
        value = re.search(week_pattern, age_str).group(1)
        return int(value) * 7
    elif "day" in age_str:
        value = re.search(day_pattern, age_str).group(1)
        return int(value)
    else:
        print(f"Unknown pattern: {age_str}; -1 days reported")
        return int(-1)

# %%
merged_data['Age upon Intake'] = merged_data['Age upon Intake'].apply(convert_to_days)
merged_data['Age upon Outcome'] = merged_data['Age upon Outcome'].apply(convert_to_days)
merged_data.head()
# Out:
#   Animal ID Animal Type Date of Birth                         Breed  \
# 0   A521520         Dog    09/07/2006  Border Terrier/Border Collie
# 1   A664235         Cat    09/24/2013        Domestic Shorthair Mix
# 2   A664237         Cat    09/24/2013        Domestic Shorthair Mix
# 3   A664236         Cat    09/24/2013        Domestic Shorthair Mix
# 4   A664233         Dog    09/30/2010                  Pit Bull Mix
#
#           Color Intake Type Intake Condition Sex upon Intake  Age upon Intake  \
# 0     White/Tan       Stray           Normal   Spayed Female             2555
# 1  Orange/White       Stray           Normal         Unknown                7
# 2  Orange/White       Stray           Normal         Unknown                7
# 3  Orange/White       Stray           Normal         Unknown                7
# 4    Blue/White       Stray          Injured   Intact Female             1095
#
#       Intake DateTime    Outcome DateTime     Outcome Type Outcome Subtype  \
# 0 2013-10-01 07:51:00 2013-10-01 15:39:00  Return to Owner   Not Specified
# 1 2013-10-01 08:33:00 2013-10-01 10:39:00         Transfer         Partner
# 2 2013-10-01 08:33:00 2013-10-01 10:44:00         Transfer         Partner
# 3 2013-10-01 08:33:00 2013-10-01 10:44:00         Transfer         Partner
# 4 2013-10-01 08:53:00 2013-10-01 15:33:00       Euthanasia       Suffering
#
#   Sex upon Outcome  Age upon Outcome
# 0    Spayed Female              2555
# 1          Unknown                 7
# 2          Unknown                 7
# 3          Unknown                 7
# 4    Intact Female              1095

# %%
# Dropping rows with negative ages for both Age upon Intake & Age upon Outcome

pre = len(merged_data)
merged_data = merged_data.loc[merged_data['Age upon Intake'] >= 0]
post= len(merged_data)
print(f"Dropped rows due to negative Intake ages: {pre - post}")

pre2 = len(merged_data)
merged_data = merged_data.loc[merged_data['Age upon Outcome'] >= 0]
post2 = len(merged_data)
print(f"Dropped rows due to negative Outcome ages: {pre - post}")
# Out:
# Dropped rows due to negative Intake ages: 34
# Dropped rows due to negative Outcome ages: 34

# %%
merged_data.head()
# Out:
#   Animal ID Animal Type Date of Birth                         Breed  \
# 0   A521520         Dog    09/07/2006  Border Terrier/Border Collie
# 1   A664235         Cat    09/24/2013        Domestic Shorthair Mix
# 2   A664237         Cat    09/24/2013        Domestic Shorthair Mix
# 3   A664236         Cat    09/24/2013        Domestic Shorthair Mix
# 4   A664233         Dog    09/30/2010                  Pit Bull Mix
#
#           Color Intake Type Intake Condition Sex upon Intake  Age upon Intake  \
# 0     White/Tan       Stray           Normal   Spayed Female             2555
# 1  Orange/White       Stray           Normal         Unknown                7
# 2  Orange/White       Stray           Normal         Unknown                7
# 3  Orange/White       Stray           Normal         Unknown                7
# 4    Blue/White       Stray          Injured   Intact Female             1095
#
#       Intake DateTime    Outcome DateTime     Outcome Type Outcome Subtype  \
# 0 2013-10-01 07:51:00 2013-10-01 15:39:00  Return to Owner   Not Specified
# 1 2013-10-01 08:33:00 2013-10-01 10:39:00         Transfer         Partner
# 2 2013-10-01 08:33:00 2013-10-01 10:44:00         Transfer         Partner
# 3 2013-10-01 08:33:00 2013-10-01 10:44:00         Transfer         Partner
# 4 2013-10-01 08:53:00 2013-10-01 15:33:00       Euthanasia       Suffering
#
#   Sex upon Outcome  Age upon Outcome
# 0    Spayed Female              2555
# 1          Unknown                 7
# 2          Unknown                 7
# 3          Unknown                 7
# 4    Intact Female              1095

# %%
merged_data['Intake Condition'].value_counts()

# These are the identifier & counts for the intake condition column. Some are very large & some are only single animals.
# Depending on the question I want to answer, I might ultimately like to consolidate these, but first, I would like to do some checking to make sure they are accurate.
# For example, a neonate should not be an old animal, and a pet described as "aged" should not be young. 
# Pregnant and nursing animals should be female.
# Out:
# Intake Condition
# Normal        160524
# Injured        10469
# Sick            7448
# Nursing         3942
# Neonatal        1426
# Aged             553
# Medical          392
# Other            368
# Pregnant         164
# Feral            151
# Behavior          82
# Med Attn          52
# Unknown           17
# Med Urgent        11
# Neurologic        10
# Parvo              5
# Space              4
# Agonal             3
# Panleuk            1
# Congenital         1
# Name: count, dtype: int64

# %%
merged_data.loc[merged_data['Intake Condition'] == 'Neonatal'].sort_values(by = 'Age upon Intake', ascending = False)

# There are 2 year old animals being called "neonates," so that's not correct. Medically speaking, puppies/kittens are considered neonates when they're younger than 14 days (28 if you're lenient).
# I will drop any animals that are considered "neonatal" with an age upon intake <30 days.
# Out:
#        Animal ID Animal Type Date of Birth                Breed        Color  \
# 209617   A908186         Cat    06/26/2022   Domestic Shorthair       Calico
# 173726   A845298         Cat    10/27/2019   Domestic Shorthair       Torbie
# 170617   A841441         Dog    08/27/2019    Queensland Heeler         Blue
# 170618   A841441         Dog    08/27/2019    Queensland Heeler         Blue
# 172263   A843380         Dog    09/30/2019  Chihuahua Shorthair    Tan/White
# ...          ...         ...           ...                  ...          ...
# 186624   A864549         Cat    08/27/2022   Domestic Shorthair        White
# 186640   A864587         Cat    08/28/2022   Domestic Shorthair         Blue
# 201464   A891068         Cat    10/16/2023   Domestic Shorthair  Brown Tabby
# 201465   A891067         Cat    10/16/2023   Domestic Shorthair  Brown Tabby
# 184698   A861763         Cat    07/15/2022   Domestic Shorthair  Brown Tabby
#
#             Intake Type Intake Condition Sex upon Intake  Age upon Intake  \
# 209617            Stray         Neonatal   Intact Female              730
# 173726        Abandoned         Neonatal   Intact Female              730
# 170617            Stray         Neonatal   Spayed Female              730
# 170618            Stray         Neonatal   Spayed Female              730
# 172263    Public Assist         Neonatal   Intact Female              730
# ...                 ...              ...             ...              ...
# 186624  Owner Surrender         Neonatal         Unknown                0
# 186640  Owner Surrender         Neonatal   Intact Female                0
# 201464  Owner Surrender         Neonatal   Intact Female                0
# 201465  Owner Surrender         Neonatal   Intact Female                0
# 184698            Stray         Neonatal   Intact Female                0
#
#            Intake DateTime    Outcome DateTime     Outcome Type  \
# 209617 2024-06-26 11:18:00 2024-06-27 13:29:00         Transfer
# 173726 2021-10-27 17:24:00 2021-10-27 17:41:00         Transfer
# 170617 2021-08-27 15:18:00 2021-09-29 18:59:00         Adoption
# 170618 2021-08-27 15:18:00 2021-10-13 17:31:00         Adoption
# 172263 2021-09-30 11:05:00 2021-10-04 15:58:00  Return to Owner
# ...                    ...                 ...              ...
# 186624 2022-08-27 09:58:00 2022-08-28 14:39:00         Transfer
# 186640 2022-08-28 00:00:00 2022-08-29 12:46:00         Transfer
# 201464 2023-10-16 12:05:00 2023-10-18 13:55:00         Transfer
# 201465 2023-10-16 12:05:00 2023-10-18 13:55:00         Transfer
# 184698 2022-07-15 18:34:00 2022-11-17 12:02:00         Adoption
#
#        Outcome Subtype Sex upon Outcome  Age upon Outcome
# 209617         Partner    Intact Female               730
# 173726         Partner    Intact Female               730
# 170617   Not Specified    Spayed Female               730
# 170618   Not Specified    Spayed Female               730
# 172263   Not Specified    Intact Female               730
# ...                ...              ...               ...
# 186624         Partner          Unknown                 1
# 186640         Partner    Intact Female                 1
# 201464         Partner    Intact Female                 2
# 201465         Partner    Intact Female                 2
# 184698          Foster    Spayed Female               120
#
# [1426 rows x 15 columns]

# %%
merged_data.loc[(merged_data['Intake Condition'] == 'Aged') & (merged_data['Age upon Intake'] < 1460)].sort_values(by = 'Age upon Intake', ascending = True)

# There is no concrete ages at which an animal becomes "aged," and an animal who has had a hard life can appear "aged" before they are really old. 
# BUT there is no situation in which a 2 day old animal should be called "aged."
# I will be lenient and say any animal under 2yr shouldn't be in the "aged" category. This also allows for exotics, which have shorter lifespans.
# Out:
#        Animal ID Animal Type Date of Birth                   Breed  \
# 200323   A888924         Cat    09/12/2023      Domestic Shorthair
# 200322   A888923         Cat    09/12/2023      Domestic Shorthair
# 199705   A887829         Cat    08/25/2023      Domestic Shorthair
# 199706   A887831         Cat    08/25/2023      Domestic Shorthair
# 199707   A887830         Cat    08/25/2023      Domestic Shorthair
# 200274   A888856         Cat    09/03/2023      Domestic Shorthair
# 200327   A888919         Cat    08/24/2023      Domestic Shorthair
# 200397   A889057         Cat    08/25/2023      Domestic Shorthair
# 163399   A831545         Cat    03/01/2021      Domestic Shorthair
# 163381   A831546         Cat    03/01/2021      Domestic Shorthair
# 163382   A831548         Cat    03/01/2021      Domestic Shorthair
# 163383   A831547         Cat    03/01/2021      Domestic Shorthair
# 163384   A831549         Cat    03/01/2021      Domestic Shorthair
# 200354   A888972         Cat    08/03/2023      Domestic Shorthair
# 815      A665169       Other    04/14/2013                 Bat Mix
# 147419   A809694         Cat    11/29/2018    Domestic Medium Hair
# 64764    A731090         Cat    07/15/2014      Domestic Shorthair
# 38303    A705044         Dog    06/12/2013  Labrador Retriever Mix
# 36070    A702931       Other    11/19/2012             Hamster Mix
# 16380    A683023         Cat    07/06/2012  Domestic Shorthair Mix
# 200655   A889532         Cat    09/23/2021      Domestic Shorthair
#
#                      Color         Intake Type Intake Condition  \
# 200323               Black               Stray             Aged
# 200322              Tortie               Stray             Aged
# 199705         Brown Tabby     Owner Surrender             Aged
# 199706         Black/White     Owner Surrender             Aged
# 199707         Brown Tabby     Owner Surrender             Aged
# 200274              Tortie               Stray             Aged
# 200327   Cream Tabby/White               Stray             Aged
# 200397        Orange/White               Stray             Aged
# 163399         Black/White               Stray             Aged
# 163381         Black/White               Stray             Aged
# 163382  Orange Tabby/White               Stray             Aged
# 163383         Black/White               Stray             Aged
# 163384         Cream Tabby               Stray             Aged
# 200354   Brown Tabby/White               Stray             Aged
# 815                   Gray            Wildlife             Aged
# 147419          Blue/White               Stray             Aged
# 64764               Torbie     Owner Surrender             Aged
# 38303          Black/White               Stray             Aged
# 36070           White/Gray  Euthanasia Request             Aged
# 16380   Orange Tabby/White               Stray             Aged
# 200655        Calico/White               Stray             Aged
merged_data = merged_data[(merged_data['Intake Condition'] != 'Neonatal') |
                            (merged_data['Age upon Intake'] < 30)]

merged_data = merged_data[(merged_data['Intake Condition'] != 'Aged') |
                          (merged_data['Age upon Intake'] > 730)]

# %% [markdown]
# ##### Reproductive status - Pregnant & Nursing

# %%
merged_data.loc[(merged_data['Intake Condition'] == 'Pregnant') &
                (merged_data['Sex upon Intake'] != 'Intact Female')]

# There are a fair number of animals listed as pregnant that are male or spayed. 
# Since I can't trust this information, I will drop these ones too.
# Out:
#        Animal ID Animal Type Date of Birth  \
# 34543    A701482         Cat    04/30/2014
# 34544    A701482         Cat    04/30/2014
# 36678    A703551         Cat    05/26/2015
# 62163    A599849         Dog    12/12/2004
# 64823    A731133         Dog    07/17/2016
# 64824    A731134         Dog    07/17/2016
# 64826    A731136         Dog    07/17/2016
# 64828    A731138         Dog    07/17/2016
# 130953   A793977         Dog    05/02/2017
# 130954   A793977         Dog    05/02/2017
# 130955   A793977         Dog    05/02/2017
# 152486   A814697         Dog    03/04/2018
# 154109   A817504         Cat    06/26/2019
# 163672   A832146         Cat    04/08/2016
# 170581   A841407         Cat    08/27/2018
# 171309   A842200         Dog    09/11/2019
# 171793   A842777         Dog    09/18/2021
# 171796   A842769         Dog    10/06/2021
# 171797   A842770         Dog    09/18/2021
# 171798   A842776         Dog    09/18/2021
# 171799   A842772         Dog    09/18/2021
# 171800   A842775         Dog    09/18/2021
# 171802   A842773         Dog    09/18/2021
# 171803   A842771         Dog    09/18/2021
# 184321   A861112         Dog    06/07/2022
# 184322   A861113         Dog    06/07/2022
# 194923   A880189         Dog    05/05/2023
# 194924   A880186         Dog    05/05/2023
# 194925   A880187         Dog    05/05/2023
# 194927   A880188         Dog    05/05/2023
# 198258   A885138         Cat    07/14/2021
# 203907   A896111         Dog    11/14/2023
# 203910   A896110         Dog    11/14/2023
# 203911   A896106         Dog    11/14/2023
# 203915   A896109         Dog    11/14/2023
# 203916   A896112         Dog    11/14/2023
#
#                                            Breed              Color  \
# 34543                      Domestic Longhair Mix        Brown Tabby
# 34544                      Domestic Longhair Mix        Brown Tabby
# 36678                     Domestic Shorthair Mix        Brown Tabby
# 62163                                   Pit Bull        Black/White
# 64823                   Jack Russell Terrier Mix              Sable
# 64824                   Jack Russell Terrier Mix          Black/Tan
# 64826                   Jack Russell Terrier Mix        White/Brown
# 64828                   Jack Russell Terrier Mix           Tricolor
# 130953                     Australian Kelpie Mix        Brown/White
# 130954                     Australian Kelpie Mix        Brown/White
# 130955                     Australian Kelpie Mix        Brown/White
# 152486                          American Bulldog        White/Brown
# 154109                        Domestic Shorthair   Blue Tabby/White
# 163672                        Domestic Shorthair   Blue Tabby/White
# 170581                        Domestic Shorthair        Brown Tabby
# 171309                                       Pug      Brown Brindle
# 171793                                  Pit Bull              Black
# 171796                   Pit Bull/Siberian Husky        Black/White
# 171797                                  Pit Bull              Black
# 171798                                  Pit Bull              Black
# 171799                                  Pit Bull              Black
# 171800                                  Pit Bull              Black
# 171802                                  Pit Bull              Black
# 171803                                  Pit Bull              Black
# 184321                                  Pit Bull              White
# 184322                                  Pit Bull        Brown/White
# 198258   Not Specified    Spayed Female               730
# 203907   Not Specified    Neutered Male                60
# 203910   Not Specified    Neutered Male                60
# 203911   Not Specified      Intact Male                30
# 203915   Not Specified    Neutered Male                60
# 203916   Not Specified    Neutered Male                60

# %%
#Sanity checked - male/spayed female pregnant

merged_data = merged_data.loc[(merged_data['Intake Condition'] != 'Pregnant') |
                (merged_data['Sex upon Intake'] == 'Intact Female')]

# %%
# Lastly, I want to look more closely at the "nursing" intake condition. These animals might refer to the nursing bitches (and thus should also be female) or to the nursing puppies. 

merged_data.loc[(merged_data['Intake Condition'] == 'Nursing') &
                (merged_data['Age upon Intake'] > 60)].sort_values(by = 'Age upon Intake')

# It looks like the shelter mostly uses "Nursing" to indicate nursing puppies/kittens. 
# HOWEVER, about 10% of the Nursing animals are over 8wks old (when puppies, kittens, and rabbits should be done nursing)
# And some are old enough that these are bitches/queens. There are also a few older males included; I will drop these. 
# I would like to split the young-nursing animals into another group (as being a cute puppy likely increases your odds of adoption)
# and keep the older-nursing females in a separate category (as being an older animal who has nursed recently might also change your odds of adoption).
# Out:
#        Animal ID Animal Type Date of Birth                    Breed  \
# 8024     A673721       Other    11/01/2013            Rabbit Sh Mix
# 133863   A796707         Cat    02/04/2019       Domestic Shorthair
# 8023     A673722       Other    11/01/2013            Rabbit Sh Mix
# 8022     A673723       Other    11/01/2013            Rabbit Sh Mix
# 8021     A673720       Other    11/01/2013            Rabbit Sh Mix
# ...          ...         ...           ...                      ...
# 140985   A803389         Dog    09/05/2012          Doberman Pinsch
# 164984   A775493         Dog    07/03/2012  Chihuahua Shorthair Mix
# 71981    A737659         Dog    11/02/2008  Chihuahua Shorthair Mix
# 73755    A739289         Cat    11/30/2007   Domestic Shorthair Mix
# 34274    A701255         Dog    04/26/2006             Shih Tzu Mix
#
#               Color    Intake Type Intake Condition Sex upon Intake  \
# 8024    Black/White  Public Assist          Nursing   Intact Female
# 133863  Brown Tabby          Stray          Nursing         Unknown
# 8023    Black/White  Public Assist          Nursing   Intact Female
# 8022     Blue/White  Public Assist          Nursing   Intact Female
# 8021    Black/White  Public Assist          Nursing   Intact Female
# ...             ...            ...              ...             ...
# 140985        Brown          Stray          Nursing   Intact Female
# 164984    Tan/White          Stray          Nursing   Spayed Female
# 71981         Black          Stray          Nursing   Neutered Male
# 73755          Blue          Stray          Nursing   Spayed Female
# 34274         White          Stray          Nursing   Neutered Male
#
#         Age upon Intake     Intake DateTime    Outcome DateTime Outcome Type  \
# 8024                 90 2014-03-01 10:12:00 2014-03-05 16:20:00     Transfer
# 133863               90 2019-06-04 15:32:00 2019-06-04 18:35:00     Transfer
# 8023                 90 2014-03-01 10:12:00 2014-03-05 16:21:00     Transfer
# 8022                 90 2014-03-01 10:12:00 2014-03-05 16:21:00     Transfer
# 8021                 90 2014-03-01 10:12:00 2014-03-05 16:19:00     Transfer
# ...                 ...                 ...                 ...          ...
# 140985             2190 2019-08-31 13:41:00 2019-09-06 16:49:00     Adoption
# 164984             2920 2021-05-11 08:12:00 2021-05-11 12:38:00     Transfer
# 71981              2920 2016-11-02 11:38:00 2017-01-08 14:59:00     Adoption
# 73755              3285 2016-11-30 12:38:00 2017-01-15 14:25:00     Adoption
# 34274              3285 2015-04-26 13:47:00 2015-05-07 00:00:00     Transfer
#
#        Outcome Subtype Sex upon Outcome  Age upon Outcome
# 8024           Partner    Intact Female               120
# 133863         Partner          Unknown                90
# 8023           Partner    Intact Female               120
# 8022           Partner    Intact Female               120
# 8021           Partner    Intact Female               120
# ...                ...              ...               ...
# 140985   Not Specified    Spayed Female              2555
# 164984         Partner    Spayed Female              2920
# 71981    Not Specified    Neutered Male              2920
# 73755    Not Specified    Spayed Female              3285
# 34274          Partner    Neutered Male              3285
#
# [374 rows x 15 columns]

# %%
# Animals younger than 60 days (aka 8.5 weeks) will now have the Intake Condition "Nursing Juvenile"

young_nursing = merged_data.loc[(merged_data['Intake Condition'] == 'Nursing') &
                                (merged_data['Age upon Intake'] <= 60)].index
merged_data['Intake Condition'][young_nursing] = 'Nursing Juvenile'
merged_data.loc[(merged_data['Intake Condition'] == 'Nursing Juvenile') &
                                (merged_data['Age upon Intake'] <= 60)]
# Out:
# C:\Users\wisery\AppData\Local\Temp\ipykernel_36876\1473088314.py:5: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   merged_data['Intake Condition'][young_nursing] = 'Nursing Juvenile'
#        Animal ID Animal Type Date of Birth                   Breed  \
# 39       A664285         Cat    10/01/2013  Domestic Shorthair Mix
# 40       A664284         Cat    10/01/2013  Domestic Shorthair Mix
# 94       A664346         Cat    09/17/2013  Domestic Shorthair Mix
# 95       A664347         Cat    09/17/2013  Domestic Shorthair Mix
# 96       A664344         Cat    09/17/2013  Domestic Shorthair Mix
# ...          ...         ...           ...                     ...
# 169686   A840467         Cat    08/02/2021      Domestic Shorthair
# 169687   A840468         Cat    08/02/2021      Domestic Shorthair
# 169688   A840470         Cat    08/02/2021      Domestic Shorthair
# 169689   A840471         Cat    08/02/2021      Domestic Shorthair
# 169746   A840530         Cat    08/01/2021    Domestic Medium Hair
#
#                     Color Intake Type  Intake Condition Sex upon Intake  \
# 39                  Black       Stray  Nursing Juvenile     Intact Male
# 40            Black/White       Stray  Nursing Juvenile     Intact Male
# 94      Black Tabby/White       Stray  Nursing Juvenile     Intact Male
# 95             Blue Tabby       Stray  Nursing Juvenile     Intact Male
# 96             White/Blue       Stray  Nursing Juvenile     Intact Male
# ...                   ...         ...               ...             ...
# 169686        Cream/White   Abandoned  Nursing Juvenile     Intact Male
# 169687              Cream   Abandoned  Nursing Juvenile     Intact Male
# 169688             Orange   Abandoned  Nursing Juvenile   Intact Female
# 169689             Orange   Abandoned  Nursing Juvenile     Intact Male
# 169746             Orange       Stray  Nursing Juvenile     Intact Male
#
#         Age upon Intake     Intake DateTime    Outcome DateTime Outcome Type  \
# 39                    0 2013-10-01 15:20:00 2013-10-02 11:03:00         Died
# 40                    0 2013-10-01 15:20:00 2013-10-02 11:02:00         Died
# 94                   14 2013-10-02 12:21:00 2013-10-02 14:27:00     Transfer
# 95                   14 2013-10-02 12:21:00 2013-10-02 14:28:00     Transfer
# 96                   14 2013-10-02 12:21:00 2013-10-02 14:25:00     Transfer
# ...                 ...                 ...                 ...          ...
# 169686                7 2021-08-09 10:41:00 2021-08-09 15:00:00     Transfer
# 169687                7 2021-08-09 10:41:00 2021-08-09 15:00:00     Transfer
# 169688                7 2021-08-09 10:41:00 2021-08-09 15:00:00     Transfer
# 169689                7 2021-08-09 10:41:00 2021-08-09 15:00:00     Transfer
# 169746                7 2021-08-10 07:01:00 2021-08-10 11:46:00     Transfer
#
#        Outcome Subtype Sex upon Outcome  Age upon Outcome
# 39           In Foster      Intact Male                 1
# 40           In Foster      Intact Male                 1
# 94             Partner      Intact Male                14
# 95             Partner      Intact Male                14
# 96             Partner      Intact Male                14
# ...                ...              ...               ...
# 169686         Partner      Intact Male                 7
# 169687         Partner      Intact Male                 7
# 169688         Partner    Intact Female                 7
# 169689         Partner      Intact Male                 7
# 169746         Partner      Intact Male                 7
#
# [3568 rows x 15 columns]

# %%
# Female animals older than 4 months (the youngest age at which a female could be nursing for dogs/cats/rabbits/guinea pigs, which are the only species represented as nursing in this data)

nursing_adults = merged_data.loc[(merged_data['Intake Condition'] == 'Nursing') &
                                 (merged_data['Age upon Intake'] > 120) &
                                 ((merged_data['Sex upon Intake'] == 'Intact Female') |
                                 (merged_data['Sex upon Intake'] == 'Spayed Female'))].index
merged_data['Intake Condition'][nursing_adults] = 'Nursing Adult'
merged_data['Intake Condition'].unique()
# Out:
# C:\Users\wisery\AppData\Local\Temp\ipykernel_36876\308785821.py:7: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   merged_data['Intake Condition'][nursing_adults] = 'Nursing Adult'
# C:\Users\wisery\AppData\Local\Temp\ipykernel_36876\308785821.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_data['Intake Condition'][nursing_adults] = 'Nursing Adult'
# array(['Normal', 'Injured', 'Nursing Juvenile', 'Nursing Adult', 'Sick',
#        'Other', 'Pregnant', 'Aged', 'Feral', 'Nursing', 'Medical',
#        'Behavior', 'Unknown', 'Neonatal', 'Space', 'Panleuk',
#        'Med Urgent', 'Med Attn', 'Agonal', 'Neurologic', 'Parvo',
#        'Congenital'], dtype=object)

# %%
# Any animals lefts in the 'Nursing' Intake condition are now either male adults or age-ambiguous enough that I can't tell whether they are the mothers or the juveniles. These will be dropped.

merged_data = merged_data.loc[(merged_data['Intake Condition'] != 'Nursing')]
merged_data['Intake Condition'].unique()
# Out:
# array(['Normal', 'Injured', 'Nursing Juvenile', 'Nursing Adult', 'Sick',
#        'Other', 'Pregnant', 'Aged', 'Feral', 'Medical', 'Behavior',
#        'Unknown', 'Neonatal', 'Space', 'Panleuk', 'Med Urgent',
#        'Med Attn', 'Agonal', 'Neurologic', 'Parvo', 'Congenital'],
#       dtype=object)

# %% [markdown]
# #### Ease of Use - Splitting Sex & Reproductive Status

# %%
# The animal industry often refers to Sex and Reproductive Status in one phrase (ex. Intact Female), so it is stored as 
# one column in this data set. However, there are actually two bits of information stored in that phrase. I would prefer
# to split this over two features so we can more easily ask questions about sex and reproductive status independently.
# Sex would then be a static categorical over the pet's life (so no 'upon intake'/'upon outcome' separator necessary). 
# Since a pet might come to the shelter intact and leave as neutered, I will keep the 'upon intake'/'upon outcome' separator
# for reproductive status. I will use "Altered" in place of "spayed" or "neutered" to consolidate to a sex-neutral term.

merged_data['Sex upon Intake'].unique()
# Out:
# array(['Spayed Female', 'Unknown', 'Intact Female', 'Intact Male',
#        'Neutered Male'], dtype=object)

# %%
def split_sex_and_repro(row):
    sex_upon_intake = row['Sex upon Intake']
    sex_upon_outcome = row['Sex upon Outcome']
    
    # Define a dictionary mapping intake/outcome statuses to sex and reproductive status
    status_mapping = {
        'Spayed Female': {'sex': 'Female', 'repro_status': 'Altered'},
        'Intact Female': {'sex': 'Female', 'repro_status': 'Intact'},
        'Neutered Male': {'sex': 'Male', 'repro_status': 'Altered'},
        'Intact Male': {'sex': 'Male', 'repro_status': 'Intact'},
    }
    
    # Determine sex based on intake status
    sex_info = status_mapping.get(sex_upon_intake, {'sex': 'Unknown', 'repro_status': 'Unknown'})
    sex = sex_info['sex']
    repro_status_in = sex_info['repro_status']
    
    # Determine reproductive status based on outcome status, keeping sex unchanged
    repro_status_out = status_mapping.get(sex_upon_outcome, {'sex': 'Unknown', 'repro_status': 'Unknown'}).get('repro_status', 'Unknown')
        
    return sex, repro_status_in, repro_status_out

# %%
merged_data['Sex'], merged_data['Intake Reproductive Status'], merged_data['Outcome Reproductive Status'] = zip(*merged_data.apply(split_sex_and_repro, axis=1))

# %%
merged_data = merged_data.drop(['Sex upon Intake', 'Sex upon Outcome'], axis = 1)
merged_data
# Out:
#        Animal ID Animal Type Date of Birth                         Breed  \
# 0        A521520         Dog    09/07/2006  Border Terrier/Border Collie
# 1        A664235         Cat    09/24/2013        Domestic Shorthair Mix
# 2        A664237         Cat    09/24/2013        Domestic Shorthair Mix
# 3        A664236         Cat    09/24/2013        Domestic Shorthair Mix
# 4        A664233         Dog    09/30/2010                  Pit Bull Mix
# ...          ...         ...           ...                           ...
# 209639   A908372         Cat    06/25/2024        Domestic Shorthair Mix
# 209640   A908375         Cat    06/25/2024        Domestic Shorthair Mix
# 209641   A908376         Cat    06/25/2024        Domestic Shorthair Mix
# 209642   A908374         Cat    06/25/2024        Domestic Shorthair Mix
# 209643   A908397       Other    05/29/2024                       Raccoon
#
#                Color Intake Type Intake Condition  Age upon Intake  \
# 0          White/Tan       Stray           Normal             2555
# 1       Orange/White       Stray           Normal                7
# 2       Orange/White       Stray           Normal                7
# 3       Orange/White       Stray           Normal                7
# 4         Blue/White       Stray          Injured             1095
# ...              ...         ...              ...              ...
# 209639          Blue       Stray           Normal                3
# 209640          Blue       Stray           Normal                3
# 209641         Black       Stray           Normal                3
# 209642          Blue       Stray           Normal                3
# 209643    Gray/Black    Wildlife           Normal               28
#
#            Intake DateTime    Outcome DateTime     Outcome Type  \
# 0      2013-10-01 07:51:00 2013-10-01 15:39:00  Return to Owner
# 1      2013-10-01 08:33:00 2013-10-01 10:39:00         Transfer
# 2      2013-10-01 08:33:00 2013-10-01 10:44:00         Transfer
# 3      2013-10-01 08:33:00 2013-10-01 10:44:00         Transfer
# 4      2013-10-01 08:53:00 2013-10-01 15:33:00       Euthanasia
# ...                    ...                 ...              ...
# 209639 2024-06-28 16:29:00 2024-06-28 18:44:00         Transfer
# 209640 2024-06-28 16:29:00 2024-06-28 18:45:00         Transfer
# 209641 2024-06-28 16:29:00 2024-06-28 18:45:00         Transfer
# 209642 2024-06-28 16:29:00 2024-06-28 18:44:00         Transfer
# 209643 2024-06-29 10:18:00 2024-06-30 12:29:00       Euthanasia
#
#        Outcome Subtype  Age upon Outcome      Sex Intake Reproductive Status  \
# 0        Not Specified              2555   Female                    Altered
# 1              Partner                 7  Unknown                    Unknown
# 2              Partner                 7  Unknown                    Unknown
# 3              Partner                 7  Unknown                    Unknown
# 4            Suffering              1095   Female                     Intact
# ...                ...               ...      ...                        ...
# 209639         Partner                 3     Male                     Intact
# 209640         Partner                 3   Female                     Intact
# 209641         Partner                 3     Male                     Intact
# 209642         Partner                 3     Male                     Intact
# 209643     Rabies Risk                28  Unknown                    Unknown
#
#        Outcome Reproductive Status
# 0                          Altered
# 1                          Unknown
# 2                          Unknown
# 3                          Unknown
# 4                           Intact
# ...                            ...
# 209639                      Intact
# 209640                      Intact
# 209641                      Intact
# 209642                      Intact
# 209643                     Unknown
#
# [185449 rows x 16 columns]

# %%
merged_data = merged_data.rename({'Age upon Intake': 'Intake Age', 'Age upon Outcome':'Outcome Age'}, axis='columns')
merged_data = merged_data.reindex(columns = ['Animal ID', 'Animal Type', 'Date of Birth', 'Sex', 'Breed', 'Color', 'Intake Type', 'Intake Condition', 'Intake Age', 'Intake Reproductive Status', 'Intake DateTime', 'Outcome DateTime', 'Outcome Type', 'Outcome Subtype', 'Outcome Age', 'Outcome Reproductive Status'])
merged_data.head()
# Out:
#   Animal ID Animal Type Date of Birth      Sex                         Breed  \
# 0   A521520         Dog    09/07/2006   Female  Border Terrier/Border Collie
# 1   A664235         Cat    09/24/2013  Unknown        Domestic Shorthair Mix
# 2   A664237         Cat    09/24/2013  Unknown        Domestic Shorthair Mix
# 3   A664236         Cat    09/24/2013  Unknown        Domestic Shorthair Mix
# 4   A664233         Dog    09/30/2010   Female                  Pit Bull Mix
#
#           Color Intake Type Intake Condition  Intake Age  \
# 0     White/Tan       Stray           Normal        2555
# 1  Orange/White       Stray           Normal           7
# 2  Orange/White       Stray           Normal           7
# 3  Orange/White       Stray           Normal           7
# 4    Blue/White       Stray          Injured        1095
#
#   Intake Reproductive Status     Intake DateTime    Outcome DateTime  \
# 0                    Altered 2013-10-01 07:51:00 2013-10-01 15:39:00
# 1                    Unknown 2013-10-01 08:33:00 2013-10-01 10:39:00
# 2                    Unknown 2013-10-01 08:33:00 2013-10-01 10:44:00
# 3                    Unknown 2013-10-01 08:33:00 2013-10-01 10:44:00
# 4                     Intact 2013-10-01 08:53:00 2013-10-01 15:33:00
#
#       Outcome Type Outcome Subtype  Outcome Age Outcome Reproductive Status
# 0  Return to Owner   Not Specified         2555                     Altered
# 1         Transfer         Partner            7                     Unknown
# 2         Transfer         Partner            7                     Unknown
# 3         Transfer         Partner            7                     Unknown
# 4       Euthanasia       Suffering         1095                      Intact

# %%
# At this point, I think my data is cleaned enough and complete enough to be used to answer a wide range of questions about this shelter animal population. 
# I'm going to end off here, so I can start my data exploration and analysis in a fresh notebook!
